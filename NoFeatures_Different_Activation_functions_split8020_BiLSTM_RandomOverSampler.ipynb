# %%
# Connect to Google Drive 
# Upload the dataset to your Google drive so it can be loaded here

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# First we import the required libraries

import tensorflow as tf
import random
import numpy as np
import pandas as pd
import matplotlib.image  as mpimg
import matplotlib.pyplot as plt
import io
import re
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import regularizers
from tensorflow.keras import backend as K 
K.clear_session()

# Check tensorflow version
if float(tf.__version__[0]) < 2.0:
  print('Updating tensorflow')
  # !pip install tensorflow==2.0
else:
  print('Correct version of Tensorflow installed.')
# Out:
# Correct version of Tensorflow installed.

# %%
# import pandas lib as pd
import pandas as pd
 
# read by default 1st sheet of an excel file
df = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/Testing FNH dataset/RandomOverSampler.xlsx', 'Sheet1')
 
print(df)
df = df.fillna(' ')
df.count()
# Out:
#                                                    Title   Len  \
# 0      Psa: ben stiller speaks out against shaken man...   132
# 1      States take back hundreds of thousands of vacc...  7449
# 2      On the brink: 16 hours til shutdown – cnn poll...  1357
# 3      The us is getting a third coronavirus vaccine....  7855
# 4      Coronavirus variant will likely drive a new wa...  3017
# ...                                                  ...   ...
# 14860  Cops, firefighters challenge gainesville's 'od...   446
# 14861  De blasio dodges on high school admissions tes...  3177
# 14862  Defense dept. issues covid "vaccination record...   255
# 14863  Alaska: cheating husband emasculated after wif...   986
# 14864  Woman who drinks 6 cups of coffee per day tryi...   914
#
#                                                  Content  \
# 0      Actor ben stiller urges parents with adult kid...
# 1      Hundreds of thousands of covid-19 vaccine dose...
# 2      a veteran of the shutdown battles of the mid-1...
# 3      The united states is getting a third coronavir...
# 4      we now are aiming to deliver a second hundred ...
# ...                                                  ...
# 14860  Seldon childers of childers law for the city: ...
# 14861  Brooklyn latin school, staten island technical...
# 14862  Tim young  december 3, 2020 the frontrunning v...
# 14863  Rosetta white, 36, was arrested this week afte...
# 14864  Saying she would stop looking at her phone and...
#
#                                                   Source Publishing Date  \
# 0      https://www.theonion.com/psa-ben-stiller-speak...      2011-03-16
# 1      https://www.cnn.com/2021/02/03/health/states-t...      2021-02-04
# 2      https://www.politico.com/tipsheets/huddle/2013...      2013-09-30
# 3      https://www.cnn.com/2021/02/27/health/johnson-...      2021-02-28
# 4      https://www.cnn.com/2021/02/23/health/us-coron...      2021-02-23
# ...                                                  ...             ...
# 14860  https://www.reuters.com/legal/government/cops-...      2021-08-28
# 14861  https://www.politico.com/newsletters/new-york-...      2018-03-16
# 14862  https://conservativedailypost.com/defense-dept...      2020-12-05
# 14863  https://worldnewsdailyreport.com/alaska-cheati...      2019-06-15
# 14864  https://www.theonion.com/woman-who-drinks-6-cu...      2017-04-04
#
#        Label
# 0          1
# 1          0
# 2          0
# 3          0
# 4          0
# ...      ...
# 14860      0
# 14861      0
# 14862      1
# 14863      1
# 14864      1
#
# [14865 rows x 6 columns]
# Title              14865
# Len                14865
# Content            14865
# Source             14865
# Publishing Date    14865
# Label              14865
# dtype: int64

# %%
# Normalize the dataset
def normalize(data):
    normalized = []
    for i in data:
        i = i.lower()
        # get rid of urls
        i = re.sub('https?://\S+|www\.\S+', '', i)
        # get rid of non words and extra spaces
        i = re.sub('\\W', ' ', i)
        i = re.sub('\n', '', i)
        i = re.sub(' +', ' ', i)
        i = re.sub('^ ', '', i)
        i = re.sub(' $', '', i)
        normalized.append(i)
    return normalized

df['Content'] = normalize(df['Content'])

# %%
# Tokenize text

tokenizer = Tokenizer()
tokenizer.fit_on_texts(df['Content'])
word_index = tokenizer.word_index
vocab_size=len(word_index)
print(vocab_size)

# Padding data

sequences = tokenizer.texts_to_sequences(df['Content'])
padded = pad_sequences(sequences, maxlen=500, padding='post', truncating='post')
# Out:
# 90999

# %%
# Spliting data - withom random shuffle
split = 0.2
split_n = int(round(len(padded)*(1-split),0))

train_data = padded[:split_n]
train_labels = df['Label'].values[:split_n]
test_data = padded[split_n:]
test_labels = df['Label'].values[split_n:]

print("Train label","/n",train_labels)
print("/nTest label","/n",test_labels)

print(type(train_data))
print(len(train_data))
print(type(train_labels))
print(len(train_labels))
# Out:
# Train label /n [1 0 0 ... 1 0 1]
# /nTest label /n [1 1 1 ... 1 1 1]
# <class 'numpy.ndarray'>
# 11892
# <class 'numpy.ndarray'>
# 11892

# %%
# Import tensor representations for words - GloVe Embedding
# !wget --no-check-certificate \
    https://storage.googleapis.com/laurencemoroney-blog.appspot.com/glove.6B.100d.txt \
    -O /tmp/glove.6B.100d.txt
embeddings_index = {};
with open('/content/drive/MyDrive/Colab Notebooks/glove.6B.100d.txt') as f:
    for line in f:
        values = line.split();
        word = values[0];
        coefs = np.asarray(values[1:], dtype='float32');
        embeddings_index[word] = coefs;
print(len(coefs))

embeddings_matrix = np.zeros((vocab_size+1, 100));
for word, i in word_index.items():
    embedding_vector = embeddings_index.get(word);
    if embedding_vector is not None:
        embeddings_matrix[i] = embedding_vector;
# Out:
# --2023-02-20 03:43:02--  https://storage.googleapis.com/laurencemoroney-blog.appspot.com/glove.6B.100d.txt
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.68.128, 74.125.24.128, 142.250.4.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.68.128|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2023-02-20 03:43:03 ERROR 404: Not Found.
#
# 100

# %% [markdown]
# **Model with Activation Function = Relu**

# %%
# Build the architecture of the RNN model - Activation Function = Relu
     
model_BiLSTM_relu = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size+1, 100, weights=[embeddings_matrix], trainable=False),
    tf.keras.layers.Conv1D(64, 5, activation='relu'),
    tf.keras.layers.MaxPooling1D(pool_size=4),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(20,  return_sequences=True)),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(20)),  
    tf.keras.layers.Dense(512),
    tf.keras.layers.Dropout(0.3),  
    tf.keras.layers.Dense(256),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# %%
model_BiLSTM_relu.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
model_BiLSTM_relu.summary()

history_BiLSTM_relu = model_BiLSTM_relu.fit(train_data, train_labels, epochs=44, batch_size=200, validation_data=[test_data, test_labels])

print("Training Complete")
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, None, 100)         9100000
#
#  conv1d (Conv1D)             (None, None, 64)          32064
#
#  max_pooling1d (MaxPooling1D  (None, None, 64)         0
#  )
#
#  bidirectional (Bidirectiona  (None, None, 40)         13600
#  l)
#
#  bidirectional_1 (Bidirectio  (None, 40)               9760
#  nal)
#
#  dense (Dense)               (None, 512)               20992
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dense_2 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 9,308,001
# Trainable params: 208,001
# Non-trainable params: 9,100,000
# _________________________________________________________________
# Epoch 1/44
# 60/60 [==============================] - 22s 56ms/step - loss: 0.5603 - accuracy: 0.7154 - val_loss: 0.5105 - val_accuracy: 0.7565
# Epoch 2/44
# 60/60 [==============================] - 2s 30ms/step - loss: 0.4446 - accuracy: 0.8023 - val_loss: 0.4135 - val_accuracy: 0.8130
# Epoch 3/44
# 60/60 [==============================] - 2s 31ms/step - loss: 0.3266 - accuracy: 0.8643 - val_loss: 0.3402 - val_accuracy: 0.8547
# Epoch 4/44
# 60/60 [==============================] - 2s 30ms/step - loss: 0.2444 - accuracy: 0.9009 - val_loss: 0.2409 - val_accuracy: 0.9055
# Epoch 5/44
# 60/60 [==============================] - 2s 35ms/step - loss: 0.1628 - accuracy: 0.9369 - val_loss: 0.2048 - val_accuracy: 0.9300
# Epoch 6/44
# 60/60 [==============================] - 2s 34ms/step - loss: 0.0824 - accuracy: 0.9697 - val_loss: 0.2134 - val_accuracy: 0.9341
# Epoch 7/44
# 60/60 [==============================] - 2s 32ms/step - loss: 0.0545 - accuracy: 0.9789 - val_loss: 0.1927 - val_accuracy: 0.9556
# Epoch 8/44
# 60/60 [==============================] - 2s 30ms/step - loss: 0.0174 - accuracy: 0.9950 - val_loss: 0.1428 - val_accuracy: 0.9647
# Epoch 9/44
# 60/60 [==============================] - 2s 30ms/step - loss: 0.0198 - accuracy: 0.9923 - val_loss: 0.4576 - val_accuracy: 0.9166
# Epoch 10/44
# 60/60 [==============================] - 2s 32ms/step - loss: 0.0170 - accuracy: 0.9945 - val_loss: 0.1663 - val_accuracy: 0.9664
# Epoch 11/44
# 60/60 [==============================] - 2s 30ms/step - loss: 0.0315 - accuracy: 0.9876 - val_loss: 0.3464 - val_accuracy: 0.9287
# Epoch 12/44
# 60/60 [==============================] - 2s 37ms/step - loss: 0.0086 - accuracy: 0.9972 - val_loss: 0.1904 - val_accuracy: 0.9691
# Epoch 13/44
# 60/60 [==============================] - 2s 34ms/step - loss: 0.0038 - accuracy: 0.9991 - val_loss: 0.4594 - val_accuracy: 0.9334
# Epoch 14/44
# 60/60 [==============================] - 2s 31ms/step - loss: 0.0085 - accuracy: 0.9967 - val_loss: 0.4449 - val_accuracy: 0.9428
# Epoch 15/44
# 60/60 [==============================] - 2s 30ms/step - loss: 0.0264 - accuracy: 0.9907 - val_loss: 0.3640 - val_accuracy: 0.9324
# Epoch 16/44
# 60/60 [==============================] - 2s 30ms/step - loss: 0.0147 - accuracy: 0.9945 - val_loss: 0.2709 - val_accuracy: 0.9559
# Epoch 17/44
# 60/60 [==============================] - 2s 30ms/step - loss: 0.0019 - accuracy: 0.9997 - val_loss: 0.2536 - val_accuracy: 0.9606
# Epoch 18/44
# 60/60 [==============================] - 2s 30ms/step - loss: 7.1954e-04 - accuracy: 0.9998 - val_loss: 0.2365 - val_accuracy: 0.9647
# Epoch 19/44
# 60/60 [==============================] - 2s 36ms/step - loss: 6.5035e-04 - accuracy: 0.9998 - val_loss: 0.2561 - val_accuracy: 0.9630
# Epoch 20/44
# 60/60 [==============================] - 2s 33ms/step - loss: 5.9291e-04 - accuracy: 0.9998 - val_loss: 0.2549 - val_accuracy: 0.9640
# Epoch 21/44
# 60/60 [==============================] - 2s 30ms/step - loss: 5.8486e-04 - accuracy: 0.9998 - val_loss: 0.2678 - val_accuracy: 0.9630
# Epoch 22/44
# 60/60 [==============================] - 2s 30ms/step - loss: 5.4869e-04 - accuracy: 0.9998 - val_loss: 0.2663 - val_accuracy: 0.9647
# Epoch 23/44
# 60/60 [==============================] - 2s 30ms/step - loss: 5.5867e-04 - accuracy: 0.9998 - val_loss: 0.2725 - val_accuracy: 0.9637
# Epoch 24/44
# 60/60 [==============================] - 2s 30ms/step - loss: 5.3172e-04 - accuracy: 0.9998 - val_loss: 0.2679 - val_accuracy: 0.9657
# Epoch 25/44
# 60/60 [==============================] - 2s 30ms/step - loss: 4.9534e-04 - accuracy: 0.9998 - val_loss: 0.2839 - val_accuracy: 0.9633
# Epoch 26/44
# 60/60 [==============================] - 2s 36ms/step - loss: 5.3617e-04 - accuracy: 0.9998 - val_loss: 0.2718 - val_accuracy: 0.9660
# Epoch 27/44
# 60/60 [==============================] - 2s 34ms/step - loss: 5.4287e-04 - accuracy: 0.9998 - val_loss: 0.2825 - val_accuracy: 0.9650
# Epoch 28/44
# 60/60 [==============================] - 2s 30ms/step - loss: 5.6489e-04 - accuracy: 0.9998 - val_loss: 0.2788 - val_accuracy: 0.9657
# Epoch 29/44
# 60/60 [==============================] - 2s 33ms/step - loss: 5.6863e-04 - accuracy: 0.9998 - val_loss: 0.2763 - val_accuracy: 0.9664
# Epoch 30/44
# 60/60 [==============================] - 2s 30ms/step - loss: 5.1493e-04 - accuracy: 0.9998 - val_loss: 0.2996 - val_accuracy: 0.9620
# Epoch 31/44
# 60/60 [==============================] - 2s 30ms/step - loss: 5.0438e-04 - accuracy: 0.9998 - val_loss: 0.2905 - val_accuracy: 0.9647
# Epoch 32/44
# 60/60 [==============================] - 2s 30ms/step - loss: 5.1140e-04 - accuracy: 0.9998 - val_loss: 0.2952 - val_accuracy: 0.9647
# Epoch 33/44
# 60/60 [==============================] - 2s 36ms/step - loss: 5.0879e-04 - accuracy: 0.9998 - val_loss: 0.2914 - val_accuracy: 0.9647
# Epoch 34/44
# 60/60 [==============================] - 2s 34ms/step - loss: 5.1518e-04 - accuracy: 0.9998 - val_loss: 0.2901 - val_accuracy: 0.9657
# Epoch 35/44
# 60/60 [==============================] - 2s 30ms/step - loss: 4.8351e-04 - accuracy: 0.9998 - val_loss: 0.2974 - val_accuracy: 0.9647
# Epoch 36/44
# 60/60 [==============================] - 2s 30ms/step - loss: 5.2232e-04 - accuracy: 0.9998 - val_loss: 0.3042 - val_accuracy: 0.9643
# Epoch 37/44
# 60/60 [==============================] - 2s 30ms/step - loss: 6.0618e-04 - accuracy: 0.9998 - val_loss: 0.3128 - val_accuracy: 0.9620
# Epoch 38/44
# 60/60 [==============================] - 2s 30ms/step - loss: 4.9785e-04 - accuracy: 0.9998 - val_loss: 0.3010 - val_accuracy: 0.9640
# Epoch 39/44
# 60/60 [==============================] - 2s 30ms/step - loss: 5.0448e-04 - accuracy: 0.9998 - val_loss: 0.2869 - val_accuracy: 0.9667
# Epoch 40/44
# 60/60 [==============================] - 2s 35ms/step - loss: 5.1600e-04 - accuracy: 0.9998 - val_loss: 0.3063 - val_accuracy: 0.9640
# Epoch 41/44
# 60/60 [==============================] - 2s 34ms/step - loss: 5.5133e-04 - accuracy: 0.9998 - val_loss: 0.2850 - val_accuracy: 0.9667
# Epoch 42/44
# 60/60 [==============================] - 2s 30ms/step - loss: 5.3572e-04 - accuracy: 0.9998 - val_loss: 0.2917 - val_accuracy: 0.9654
# Epoch 43/44
# 60/60 [==============================] - 2s 30ms/step - loss: 5.0287e-04 - accuracy: 0.9998 - val_loss: 0.3054 - val_accuracy: 0.9637
# Epoch 44/44
# 60/60 [==============================] - 2s 30ms/step - loss: 4.8373e-04 - accuracy: 0.9998 - val_loss: 0.3000 - val_accuracy: 0.9654
# Training Complete

# %%
tf.keras.utils.plot_model(model_BiLSTM_relu, show_shapes=True, rankdir="LR")

# %%
# Visualize the results:

plt.plot(history_BiLSTM_relu.history['accuracy'])
plt.plot(history_BiLSTM_relu.history['val_accuracy'])
plt.title('Model accuracy - Activation function - ReLu')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

plt.plot(history_BiLSTM_relu.history['loss'])
plt.plot(history_BiLSTM_relu.history['val_loss'])
plt.title('Model loss - Activation function - ReLu')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper right')
plt.show()

# %%
pred_BiLSTM_relu = model_BiLSTM_relu.predict(test_data)

binary_predictions_BiLSTM_relu = []

for i in pred_BiLSTM_relu:
    if i >= 0.5:
        binary_predictions_BiLSTM_relu.append(1)
    else:
        binary_predictions_BiLSTM_relu.append(0)
# Out:
# 93/93 [==============================] - 2s 9ms/step

# %%
# Confusion Matrix
from sklearn.metrics import confusion_matrix

matrix = confusion_matrix(binary_predictions_BiLSTM_relu, test_labels)
plt.figure(figsize=(5, 5))
ax= plt.subplot()
sns.heatmap(matrix, annot=True, ax = ax, fmt = ".1f")

# labels, title and ticks
ax.set_xlabel('Predicted Labels', size=20)
ax.set_ylabel('True Labels', size=20)
ax.set_title('Confusion Matrix of BiLSTM Model with Activation function - ReLu', size=20) 
ax.xaxis.set_ticklabels(['True News','Fake News'], size=15)
ax.yaxis.set_ticklabels(['True News','Fake News'], size=15)
# Out:
# [Text(0, 0.5, 'True News'), Text(0, 1.5, 'Fake News')]

# %%
# Precision, recall, accuracy score and F1 score

from sklearn import metrics
Accuracy_BiLSTM_Relu = metrics.accuracy_score(test_labels, binary_predictions_BiLSTM_relu)
Precision_BiLSTM_Relu = metrics.precision_score(test_labels, binary_predictions_BiLSTM_relu)
Sensitivity_recall_BiLSTM_Relu = metrics.recall_score(test_labels, binary_predictions_BiLSTM_relu)
Specificity_BiLSTM_Relu = metrics.recall_score(test_labels, binary_predictions_BiLSTM_relu, pos_label=0)
F1_score_BiLSTM_Relu = metrics.f1_score(test_labels, binary_predictions_BiLSTM_relu)

print("Accuracy of Model - Activation function - ReLu =", Accuracy_BiLSTM_Relu)
print("Precision of Model - Activation function - ReLu =", Precision_BiLSTM_Relu)
print("Sensitivity_recall of Model - Activation function - ReLu =", Sensitivity_recall_BiLSTM_Relu)
print("Specificity of Model - Activation function - ReLu =", Specificity_BiLSTM_Relu)
print("F1_score of Model - Activation function - ReLu =", F1_score_BiLSTM_Relu)
# Out:
# Accuracy of Model - Activation function - ReLu = 0.9653548604103599
# Precision of Model - Activation function - ReLu = 0.9338235294117647
# Sensitivity_recall of Model - Activation function - ReLu = 0.9971448965024983
# Specificity of Model - Activation function - ReLu = 0.9370229007633588
# F1_score of Model - Activation function - ReLu = 0.9644459785985502

# %% [markdown]
# **Model with Activation function = tanh**

# %%
# Build the architecture of the RNN model - Activation Function = tanh
     
model_BiLSTM_tanh = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size+1, 100, weights=[embeddings_matrix], trainable=False),
    tf.keras.layers.Conv1D(64, 5, activation='tanh'),
    tf.keras.layers.MaxPooling1D(pool_size=4),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(20,  return_sequences=True)),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(20)),  
    tf.keras.layers.Dense(512),
    tf.keras.layers.Dropout(0.3),  
    tf.keras.layers.Dense(256),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# %%
model_BiLSTM_tanh.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
model_BiLSTM_tanh.summary()

history_BiLSTM_tanh = model_BiLSTM_tanh.fit(train_data, train_labels, epochs=44, batch_size=200, validation_data=[test_data, test_labels])

print("Training Complete")
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, None, 100)         9100000
#
#  conv1d_1 (Conv1D)           (None, None, 64)          32064
#
#  max_pooling1d_1 (MaxPooling  (None, None, 64)         0
#  1D)
#
#  bidirectional_2 (Bidirectio  (None, None, 40)         13600
#  nal)
#
#  bidirectional_3 (Bidirectio  (None, 40)               9760
#  nal)
#
#  dense_3 (Dense)             (None, 512)               20992
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_4 (Dense)             (None, 256)               131328
#
#  dense_5 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 9,308,001
# Trainable params: 208,001
# Non-trainable params: 9,100,000
# _________________________________________________________________
# Epoch 1/44
# 60/60 [==============================] - 11s 54ms/step - loss: 0.5384 - accuracy: 0.7263 - val_loss: 0.4880 - val_accuracy: 0.7837
# Epoch 2/44
# 60/60 [==============================] - 2s 30ms/step - loss: 0.4145 - accuracy: 0.8170 - val_loss: 0.4305 - val_accuracy: 0.8069
# Epoch 3/44
# 60/60 [==============================] - 2s 30ms/step - loss: 0.3625 - accuracy: 0.8422 - val_loss: 0.3313 - val_accuracy: 0.8591
# Epoch 4/44
# 60/60 [==============================] - 2s 32ms/step - loss: 0.2795 - accuracy: 0.8815 - val_loss: 0.2924 - val_accuracy: 0.8769
# Epoch 5/44
# 60/60 [==============================] - 2s 35ms/step - loss: 0.2152 - accuracy: 0.9143 - val_loss: 0.3411 - val_accuracy: 0.8644
# Epoch 6/44
# 60/60 [==============================] - 2s 31ms/step - loss: 0.1645 - accuracy: 0.9362 - val_loss: 0.2054 - val_accuracy: 0.9273
# Epoch 7/44
# 60/60 [==============================] - 2s 30ms/step - loss: 0.0764 - accuracy: 0.9730 - val_loss: 0.1892 - val_accuracy: 0.9388
# Epoch 8/44
# 60/60 [==============================] - 2s 30ms/step - loss: 0.0353 - accuracy: 0.9884 - val_loss: 0.1763 - val_accuracy: 0.9559
# Epoch 9/44
# 60/60 [==============================] - 2s 30ms/step - loss: 0.0622 - accuracy: 0.9762 - val_loss: 0.2763 - val_accuracy: 0.9290
# Epoch 10/44
# 60/60 [==============================] - 2s 30ms/step - loss: 0.0399 - accuracy: 0.9853 - val_loss: 0.2103 - val_accuracy: 0.9418
# Epoch 11/44
# 60/60 [==============================] - 2s 33ms/step - loss: 0.0157 - accuracy: 0.9949 - val_loss: 0.2432 - val_accuracy: 0.9536
# Epoch 12/44
# 60/60 [==============================] - 2s 35ms/step - loss: 0.0044 - accuracy: 0.9987 - val_loss: 0.2586 - val_accuracy: 0.9549
# Epoch 13/44
# 60/60 [==============================] - 2s 32ms/step - loss: 0.0019 - accuracy: 0.9997 - val_loss: 0.2590 - val_accuracy: 0.9603
# Epoch 14/44
# 60/60 [==============================] - 2s 30ms/step - loss: 9.1885e-04 - accuracy: 0.9998 - val_loss: 0.2621 - val_accuracy: 0.9606
# Epoch 15/44
# 60/60 [==============================] - 2s 30ms/step - loss: 8.1528e-04 - accuracy: 0.9998 - val_loss: 0.2690 - val_accuracy: 0.9593
# Epoch 16/44
# 60/60 [==============================] - 2s 30ms/step - loss: 7.3208e-04 - accuracy: 0.9998 - val_loss: 0.2909 - val_accuracy: 0.9573
# Epoch 17/44
# 60/60 [==============================] - 2s 30ms/step - loss: 6.5928e-04 - accuracy: 0.9998 - val_loss: 0.2690 - val_accuracy: 0.9600
# Epoch 18/44
# 60/60 [==============================] - 2s 33ms/step - loss: 5.8870e-04 - accuracy: 0.9998 - val_loss: 0.2925 - val_accuracy: 0.9586
# Epoch 19/44
# 60/60 [==============================] - 2s 37ms/step - loss: 5.8814e-04 - accuracy: 0.9998 - val_loss: 0.2900 - val_accuracy: 0.9586
# Epoch 20/44
# 60/60 [==============================] - 2s 32ms/step - loss: 5.5126e-04 - accuracy: 0.9998 - val_loss: 0.2871 - val_accuracy: 0.9596
# Epoch 21/44
# 60/60 [==============================] - 2s 30ms/step - loss: 5.2255e-04 - accuracy: 0.9998 - val_loss: 0.3105 - val_accuracy: 0.9573
# Epoch 22/44
# 60/60 [==============================] - 2s 30ms/step - loss: 5.8924e-04 - accuracy: 0.9998 - val_loss: 0.3300 - val_accuracy: 0.9549
# Epoch 23/44
# 60/60 [==============================] - 2s 30ms/step - loss: 6.4615e-04 - accuracy: 0.9998 - val_loss: 0.3212 - val_accuracy: 0.9563
# Epoch 24/44
# 60/60 [==============================] - 2s 30ms/step - loss: 5.4511e-04 - accuracy: 0.9998 - val_loss: 0.3016 - val_accuracy: 0.9590
# Epoch 25/44
# 60/60 [==============================] - 2s 31ms/step - loss: 5.4135e-04 - accuracy: 0.9998 - val_loss: 0.3142 - val_accuracy: 0.9576
# Epoch 26/44
# 60/60 [==============================] - 2s 37ms/step - loss: 5.5043e-04 - accuracy: 0.9998 - val_loss: 0.3191 - val_accuracy: 0.9573
# Epoch 27/44
# 60/60 [==============================] - 2s 32ms/step - loss: 5.3432e-04 - accuracy: 0.9998 - val_loss: 0.3091 - val_accuracy: 0.9590
# Epoch 28/44
# 60/60 [==============================] - 2s 30ms/step - loss: 5.8985e-04 - accuracy: 0.9998 - val_loss: 0.3052 - val_accuracy: 0.9600
# Epoch 29/44
# 60/60 [==============================] - 2s 30ms/step - loss: 4.9156e-04 - accuracy: 0.9998 - val_loss: 0.3384 - val_accuracy: 0.9543
# Epoch 30/44
# 60/60 [==============================] - 2s 30ms/step - loss: 6.1634e-04 - accuracy: 0.9998 - val_loss: 0.3077 - val_accuracy: 0.9600
# Epoch 31/44
# 60/60 [==============================] - 2s 30ms/step - loss: 5.5908e-04 - accuracy: 0.9998 - val_loss: 0.2885 - val_accuracy: 0.9627
# Epoch 32/44
# 60/60 [==============================] - 2s 34ms/step - loss: 6.2306e-04 - accuracy: 0.9998 - val_loss: 0.3133 - val_accuracy: 0.9593
# Epoch 33/44
# 60/60 [==============================] - 2s 38ms/step - loss: 6.1041e-04 - accuracy: 0.9998 - val_loss: 0.3378 - val_accuracy: 0.9563
# Epoch 34/44
# 60/60 [==============================] - 2s 31ms/step - loss: 5.7754e-04 - accuracy: 0.9998 - val_loss: 0.2958 - val_accuracy: 0.9620
# Epoch 35/44
# 60/60 [==============================] - 2s 30ms/step - loss: 5.7847e-04 - accuracy: 0.9998 - val_loss: 0.3156 - val_accuracy: 0.9596
# Epoch 36/44
# 60/60 [==============================] - 2s 30ms/step - loss: 4.9783e-04 - accuracy: 0.9998 - val_loss: 0.3172 - val_accuracy: 0.9590
# Epoch 37/44
# 60/60 [==============================] - 2s 31ms/step - loss: 6.0227e-04 - accuracy: 0.9998 - val_loss: 0.2874 - val_accuracy: 0.9630
# Epoch 38/44
# 60/60 [==============================] - 2s 31ms/step - loss: 6.5754e-04 - accuracy: 0.9997 - val_loss: 0.2864 - val_accuracy: 0.9633
# Epoch 39/44
# 60/60 [==============================] - 2s 34ms/step - loss: 6.3434e-04 - accuracy: 0.9997 - val_loss: 0.3366 - val_accuracy: 0.9553
# Epoch 40/44
# 60/60 [==============================] - 2s 35ms/step - loss: 5.9298e-04 - accuracy: 0.9998 - val_loss: 0.3484 - val_accuracy: 0.9559
# Epoch 41/44
# 60/60 [==============================] - 2s 34ms/step - loss: 5.7380e-04 - accuracy: 0.9998 - val_loss: 0.3331 - val_accuracy: 0.9583
# Epoch 42/44
# 60/60 [==============================] - 2s 33ms/step - loss: 4.8183e-04 - accuracy: 0.9998 - val_loss: 0.3601 - val_accuracy: 0.9543
# Epoch 43/44
# 60/60 [==============================] - 2s 31ms/step - loss: 7.4428e-04 - accuracy: 0.9998 - val_loss: 0.3589 - val_accuracy: 0.9543
# Epoch 44/44
# 60/60 [==============================] - 2s 30ms/step - loss: 5.5289e-04 - accuracy: 0.9998 - val_loss: 0.2875 - val_accuracy: 0.9623
# Training Complete

# %%
tf.keras.utils.plot_model(model_BiLSTM_tanh, show_shapes=True, rankdir="LR")

# %%
# Visualize the results:

plt.plot(history_BiLSTM_tanh.history['accuracy'])
plt.plot(history_BiLSTM_tanh.history['val_accuracy'])
plt.title('Model accuracy - Activation function - tanh')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

plt.plot(history_BiLSTM_tanh.history['loss'])
plt.plot(history_BiLSTM_tanh.history['val_loss'])
plt.title('Model loss - Activation function - tanh')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper right')
plt.show()

# %%
pred_BiLSTM_tanh = model_BiLSTM_tanh.predict(test_data)

binary_predictions_BiLSTM_tanh = []

for i in pred_BiLSTM_tanh:
    if i >= 0.5:
        binary_predictions_BiLSTM_tanh.append(1)
    else:
        binary_predictions_BiLSTM_tanh.append(0)
# Out:
# 93/93 [==============================] - 2s 9ms/step

# %%
# Confusion Matrix
from sklearn.metrics import confusion_matrix

matrix = confusion_matrix(binary_predictions_BiLSTM_tanh, test_labels)
plt.figure(figsize=(5, 5))
ax= plt.subplot()
sns.heatmap(matrix, annot=True, ax = ax, fmt = ".1f")

# labels, title and ticks
ax.set_xlabel('Predicted Labels', size=20)
ax.set_ylabel('True Labels', size=20)
ax.set_title('Confusion Matrix of BiLSTM Model with Activation function - tanh', size=20) 
ax.xaxis.set_ticklabels(['True News','Fake News'], size=15)
ax.yaxis.set_ticklabels(['True News','Fake News'], size=15)
# Out:
# [Text(0, 0.5, 'True News'), Text(0, 1.5, 'Fake News')]

# %%
# Precision, recall, accuracy score and F1 score

from sklearn import metrics
Accuracy_BiLSTM_tanh = metrics.accuracy_score(test_labels, binary_predictions_BiLSTM_tanh)
Precision_BiLSTM_tanh = metrics.precision_score(test_labels, binary_predictions_BiLSTM_tanh)
Sensitivity_recall_BiLSTM_tanh = metrics.recall_score(test_labels, binary_predictions_BiLSTM_tanh)
Specificity_BiLSTM_tanh = metrics.recall_score(test_labels, binary_predictions_BiLSTM_tanh, pos_label=0)
F1_score_BiLSTM_tanh = metrics.f1_score(test_labels, binary_predictions_BiLSTM_tanh)

print("Accuracy of Model - Activation function - tanh =", Accuracy_BiLSTM_tanh)
print("Precision of Model - Activation function - tanh =", Precision_BiLSTM_tanh)
print("Sensitivity_recall of Model - Activation function - tanh =", Sensitivity_recall_BiLSTM_tanh)
print("Specificity of Model - Activation function - tanh =", Specificity_BiLSTM_tanh)
print("F1_score of Model - Activation function - tanh =", F1_score_BiLSTM_tanh)
# Out:
# Accuracy of Model - Activation function - tanh = 0.9623276152034982
# Precision of Model - Activation function - tanh = 0.932260228034876
# Sensitivity_recall of Model - Activation function - tanh = 0.9921484653818701
# Specificity of Model - Activation function - tanh = 0.9357506361323156
# F1_score of Model - Activation function - tanh = 0.9612724757952974

# %% [markdown]
# **Model with Activation function = Sigmoid**

# %%
# Build the architecture of the RNN model - Activation Function = sigmoid
     
model_BiLSTM_sigmoid = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size+1, 100, weights=[embeddings_matrix], trainable=False),
    tf.keras.layers.Conv1D(64, 5, activation='sigmoid'),
    tf.keras.layers.MaxPooling1D(pool_size=4),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(20,  return_sequences=True)),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(20)),  
    tf.keras.layers.Dense(512),
    tf.keras.layers.Dropout(0.3),  
    tf.keras.layers.Dense(256),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# %%
model_BiLSTM_sigmoid.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
model_BiLSTM_sigmoid.summary()

history_BiLSTM_sigmoid = model_BiLSTM_sigmoid.fit(train_data, train_labels, epochs=44, batch_size=200, validation_data=[test_data, test_labels])

print("Training Complete")
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, None, 100)         9100000
#
#  conv1d_2 (Conv1D)           (None, None, 64)          32064
#
#  max_pooling1d_2 (MaxPooling  (None, None, 64)         0
#  1D)
#
#  bidirectional_4 (Bidirectio  (None, None, 40)         13600
#  nal)
#
#  bidirectional_5 (Bidirectio  (None, 40)               9760
#  nal)
#
#  dense_6 (Dense)             (None, 512)               20992
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_7 (Dense)             (None, 256)               131328
#
#  dense_8 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 9,308,001
# Trainable params: 208,001
# Non-trainable params: 9,100,000
# _________________________________________________________________
# Epoch 1/44
# 60/60 [==============================] - 12s 54ms/step - loss: 0.6357 - accuracy: 0.6504 - val_loss: 0.5670 - val_accuracy: 0.7242
# Epoch 2/44
# 60/60 [==============================] - 2s 32ms/step - loss: 0.5214 - accuracy: 0.7510 - val_loss: 0.4778 - val_accuracy: 0.7854
# Epoch 3/44
# 60/60 [==============================] - 2s 30ms/step - loss: 0.4616 - accuracy: 0.7883 - val_loss: 0.4123 - val_accuracy: 0.8197
# Epoch 4/44
# 60/60 [==============================] - 2s 32ms/step - loss: 0.3952 - accuracy: 0.8243 - val_loss: 0.3783 - val_accuracy: 0.8426
# Epoch 5/44
# 60/60 [==============================] - 2s 35ms/step - loss: 0.3756 - accuracy: 0.8311 - val_loss: 0.4058 - val_accuracy: 0.8207
# Epoch 6/44
# 60/60 [==============================] - 2s 32ms/step - loss: 0.2990 - accuracy: 0.8750 - val_loss: 0.3419 - val_accuracy: 0.8463
# Epoch 7/44
# 60/60 [==============================] - 2s 30ms/step - loss: 0.2384 - accuracy: 0.9007 - val_loss: 0.2647 - val_accuracy: 0.8934
# Epoch 8/44
# 60/60 [==============================] - 2s 30ms/step - loss: 0.1597 - accuracy: 0.9379 - val_loss: 0.2262 - val_accuracy: 0.9092
# Epoch 9/44
# 60/60 [==============================] - 2s 30ms/step - loss: 0.1276 - accuracy: 0.9495 - val_loss: 0.1945 - val_accuracy: 0.9354
# Epoch 10/44
# 60/60 [==============================] - 2s 30ms/step - loss: 0.0970 - accuracy: 0.9651 - val_loss: 0.1752 - val_accuracy: 0.9408
# Epoch 11/44
# 60/60 [==============================] - 2s 33ms/step - loss: 0.0292 - accuracy: 0.9911 - val_loss: 0.1955 - val_accuracy: 0.9485
# Epoch 12/44
# 60/60 [==============================] - 2s 38ms/step - loss: 0.0243 - accuracy: 0.9907 - val_loss: 0.3131 - val_accuracy: 0.9415
# Epoch 13/44
# 60/60 [==============================] - 2s 35ms/step - loss: 0.0092 - accuracy: 0.9965 - val_loss: 0.2383 - val_accuracy: 0.9398
# Epoch 14/44
# 60/60 [==============================] - 2s 30ms/step - loss: 0.0534 - accuracy: 0.9799 - val_loss: 0.2847 - val_accuracy: 0.9408
# Epoch 15/44
# 60/60 [==============================] - 2s 30ms/step - loss: 0.0132 - accuracy: 0.9959 - val_loss: 0.2231 - val_accuracy: 0.9569
# Epoch 16/44
# 60/60 [==============================] - 2s 33ms/step - loss: 0.0020 - accuracy: 0.9997 - val_loss: 0.2424 - val_accuracy: 0.9580
# Epoch 17/44
# 60/60 [==============================] - 2s 30ms/step - loss: 0.0013 - accuracy: 0.9998 - val_loss: 0.2184 - val_accuracy: 0.9667
# Epoch 18/44
# 60/60 [==============================] - 2s 32ms/step - loss: 0.0012 - accuracy: 0.9996 - val_loss: 0.2566 - val_accuracy: 0.9603
# Epoch 19/44
# 60/60 [==============================] - 2s 35ms/step - loss: 0.0010 - accuracy: 0.9998 - val_loss: 0.3035 - val_accuracy: 0.9549
# Epoch 20/44
# 60/60 [==============================] - 2s 32ms/step - loss: 0.0010 - accuracy: 0.9997 - val_loss: 0.2876 - val_accuracy: 0.9580
# Epoch 21/44
# 60/60 [==============================] - 2s 30ms/step - loss: 7.9864e-04 - accuracy: 0.9998 - val_loss: 0.3063 - val_accuracy: 0.9566
# Epoch 22/44
# 60/60 [==============================] - 2s 33ms/step - loss: 8.0882e-04 - accuracy: 0.9997 - val_loss: 0.3253 - val_accuracy: 0.9559
# Epoch 23/44
# 60/60 [==============================] - 2s 30ms/step - loss: 0.0015 - accuracy: 0.9995 - val_loss: 0.2913 - val_accuracy: 0.9603
# Epoch 24/44
# 60/60 [==============================] - 2s 32ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.3142 - val_accuracy: 0.9586
# Epoch 25/44
# 60/60 [==============================] - 2s 34ms/step - loss: 8.4154e-04 - accuracy: 0.9998 - val_loss: 0.3414 - val_accuracy: 0.9553
# Epoch 26/44
# 60/60 [==============================] - 2s 37ms/step - loss: 8.7257e-04 - accuracy: 0.9998 - val_loss: 0.2946 - val_accuracy: 0.9590
# Epoch 27/44
# 60/60 [==============================] - 2s 31ms/step - loss: 5.4071e-04 - accuracy: 0.9998 - val_loss: 0.3580 - val_accuracy: 0.9553
# Epoch 28/44
# 60/60 [==============================] - 2s 30ms/step - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.2418 - val_accuracy: 0.9677
# Epoch 29/44
# 60/60 [==============================] - 2s 30ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.4192 - val_accuracy: 0.9502
# Epoch 30/44
# 60/60 [==============================] - 2s 30ms/step - loss: 9.9037e-04 - accuracy: 0.9997 - val_loss: 0.3907 - val_accuracy: 0.9506
# Epoch 31/44
# 60/60 [==============================] - 2s 30ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.2468 - val_accuracy: 0.9704
# Epoch 32/44
# 60/60 [==============================] - 2s 33ms/step - loss: 6.8976e-04 - accuracy: 0.9997 - val_loss: 0.2678 - val_accuracy: 0.9664
# Epoch 33/44
# 60/60 [==============================] - 2s 36ms/step - loss: 8.8725e-04 - accuracy: 0.9997 - val_loss: 0.3019 - val_accuracy: 0.9606
# Epoch 34/44
# 60/60 [==============================] - 2s 31ms/step - loss: 6.1858e-04 - accuracy: 0.9998 - val_loss: 0.2101 - val_accuracy: 0.9731
# Epoch 35/44
# 60/60 [==============================] - 2s 30ms/step - loss: 0.7112 - accuracy: 0.7926 - val_loss: 0.5830 - val_accuracy: 0.6657
# Epoch 36/44
# 60/60 [==============================] - 2s 30ms/step - loss: 0.4040 - accuracy: 0.8128 - val_loss: 0.3216 - val_accuracy: 0.8665
# Epoch 37/44
# 60/60 [==============================] - 2s 30ms/step - loss: 0.1980 - accuracy: 0.9180 - val_loss: 0.2940 - val_accuracy: 0.8988
# Epoch 38/44
# 60/60 [==============================] - 2s 30ms/step - loss: 0.0682 - accuracy: 0.9770 - val_loss: 0.1844 - val_accuracy: 0.9512
# Epoch 39/44
# 60/60 [==============================] - 2s 35ms/step - loss: 0.0288 - accuracy: 0.9909 - val_loss: 0.2080 - val_accuracy: 0.9553
# Epoch 40/44
# 60/60 [==============================] - 2s 38ms/step - loss: 0.0056 - accuracy: 0.9989 - val_loss: 0.2183 - val_accuracy: 0.9606
# Epoch 41/44
# 60/60 [==============================] - 2s 31ms/step - loss: 0.0034 - accuracy: 0.9997 - val_loss: 0.2999 - val_accuracy: 0.9469
# Epoch 42/44
# 60/60 [==============================] - 2s 31ms/step - loss: 0.0015 - accuracy: 0.9998 - val_loss: 0.2767 - val_accuracy: 0.9553
# Epoch 43/44
# 60/60 [==============================] - 2s 32ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.2697 - val_accuracy: 0.9590
# Epoch 44/44
# 60/60 [==============================] - 2s 30ms/step - loss: 9.0038e-04 - accuracy: 0.9998 - val_loss: 0.2974 - val_accuracy: 0.9549
# Training Complete

# %%
tf.keras.utils.plot_model(model_BiLSTM_sigmoid, show_shapes=True, rankdir="LR")

# %%
# Visualize the results:

plt.plot(history_BiLSTM_sigmoid.history['accuracy'])
plt.plot(history_BiLSTM_sigmoid.history['val_accuracy'])
plt.title('Model accuracy - Activation function - sigmoid')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

plt.plot(history_BiLSTM_sigmoid.history['loss'])
plt.plot(history_BiLSTM_sigmoid.history['val_loss'])
plt.title('Model loss - Activation function - sigmoid')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper right')
plt.show()

# %%
pred_BiLSTM_sigmoid = model_BiLSTM_sigmoid.predict(test_data)

binary_predictions_BiLSTM_sigmoid = []

for i in pred_BiLSTM_sigmoid:
    if i >= 0.5:
        binary_predictions_BiLSTM_sigmoid.append(1)
    else:
        binary_predictions_BiLSTM_sigmoid.append(0)
# Out:
# 93/93 [==============================] - 2s 8ms/step

# %%
# Confusion Matrix
from sklearn.metrics import confusion_matrix

matrix = confusion_matrix(binary_predictions_BiLSTM_sigmoid, test_labels)
plt.figure(figsize=(5, 5))
ax= plt.subplot()
sns.heatmap(matrix, annot=True, ax = ax, fmt = ".1f")

# labels, title and ticks
ax.set_xlabel('Predicted Labels', size=20)
ax.set_ylabel('True Labels', size=20)
ax.set_title('Confusion Matrix of BiLSTM Model with Activation function - sigmoid', size=20) 
ax.xaxis.set_ticklabels(['True News','Fake News'], size=15)
ax.yaxis.set_ticklabels(['True News','Fake News'], size=15)
# Out:
# [Text(0, 0.5, 'True News'), Text(0, 1.5, 'Fake News')]

# %%
# Precision, recall, accuracy score and F1 score

from sklearn import metrics
Accuracy_BiLSTM_sigmoid = metrics.accuracy_score(test_labels, binary_predictions_BiLSTM_sigmoid)
Precision_BiLSTM_sigmoid = metrics.precision_score(test_labels, binary_predictions_BiLSTM_sigmoid)
Sensitivity_recall_BiLSTM_sigmoid = metrics.recall_score(test_labels, binary_predictions_BiLSTM_sigmoid)
Specificity_BiLSTM_sigmoid = metrics.recall_score(test_labels, binary_predictions_BiLSTM_sigmoid, pos_label=0)
F1_score_BiLSTM_sigmoid = metrics.f1_score(test_labels, binary_predictions_BiLSTM_sigmoid)

print("Accuracy of Model - Activation function - sigmoid =", Accuracy_BiLSTM_sigmoid)
print("Precision of Model - Activation function - sigmoid =", Precision_BiLSTM_sigmoid)
print("Sensitivity_recall of Model - Activation function - sigmoid) =", Sensitivity_recall_BiLSTM_sigmoid)
print("Specificity of Model - Activation function - sigmoid =", Specificity_BiLSTM_sigmoid)
print("F1_score of Model - Activation function - sigmoid =", F1_score_BiLSTM_sigmoid)
# Out:
# Accuracy of Model - Activation function - sigmoid = 0.9549276824756139
# Precision of Model - Activation function - sigmoid = 0.9187045604758758
# Sensitivity_recall of Model - Activation function - sigmoid) = 0.9921484653818701
# Specificity of Model - Activation function - sigmoid = 0.9217557251908397
# F1_score of Model - Activation function - sigmoid = 0.9540150995195608

# %% [markdown]
# **Model with Activation function = Softmax**

# %%
# Build the architecture of the RNN model - Activation Function = softmax
     
model_softmax = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size+1, 100, weights=[embeddings_matrix], trainable=False),
    tf.keras.layers.Conv1D(64, 5, activation='sigmoid'),
    tf.keras.layers.MaxPooling1D(pool_size=4),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(20,  return_sequences=True)),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(20)),  
    tf.keras.layers.Dense(512),
    tf.keras.layers.Dropout(0.3),  
    tf.keras.layers.Dense(256),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# %%
model_softmax.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
model_softmax.summary()

history_BiLSTM_softmax = model_softmax.fit(train_data, train_labels, epochs=44, batch_size=200, validation_data=[test_data, test_labels])

print("Training Complete")
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_3 (Embedding)     (None, None, 100)         9100000
#
#  conv1d_3 (Conv1D)           (None, None, 64)          32064
#
#  max_pooling1d_3 (MaxPooling  (None, None, 64)         0
#  1D)
#
#  bidirectional_6 (Bidirectio  (None, None, 40)         13600
#  nal)
#
#  bidirectional_7 (Bidirectio  (None, 40)               9760
#  nal)
#
#  dense_9 (Dense)             (None, 512)               20992
#
#  dropout_3 (Dropout)         (None, 512)               0
#
#  dense_10 (Dense)            (None, 256)               131328
#
#  dense_11 (Dense)            (None, 1)                 257
#
# =================================================================
# Total params: 9,308,001
# Trainable params: 208,001
# Non-trainable params: 9,100,000
# _________________________________________________________________
# Epoch 1/44
# 60/60 [==============================] - 11s 62ms/step - loss: 0.5937 - accuracy: 0.6903 - val_loss: 0.5212 - val_accuracy: 0.7598
# Epoch 2/44
# 60/60 [==============================] - 2s 38ms/step - loss: 0.4930 - accuracy: 0.7686 - val_loss: 0.5039 - val_accuracy: 0.7538
# Epoch 3/44
# 60/60 [==============================] - 2s 30ms/step - loss: 0.4296 - accuracy: 0.8090 - val_loss: 0.3910 - val_accuracy: 0.8311
# Epoch 4/44
# 60/60 [==============================] - 2s 30ms/step - loss: 0.3911 - accuracy: 0.8303 - val_loss: 0.3797 - val_accuracy: 0.8359
# Epoch 5/44
# 60/60 [==============================] - 2s 30ms/step - loss: 0.3348 - accuracy: 0.8571 - val_loss: 0.3342 - val_accuracy: 0.8560
# Epoch 6/44
# 60/60 [==============================] - 2s 33ms/step - loss: 0.2608 - accuracy: 0.8914 - val_loss: 0.2812 - val_accuracy: 0.8843
# Epoch 7/44
# 60/60 [==============================] - 2s 30ms/step - loss: 0.1925 - accuracy: 0.9193 - val_loss: 0.2308 - val_accuracy: 0.9136
# Epoch 8/44
# 60/60 [==============================] - 2s 36ms/step - loss: 0.1544 - accuracy: 0.9379 - val_loss: 0.2287 - val_accuracy: 0.9075
# Epoch 9/44
# 60/60 [==============================] - 2s 38ms/step - loss: 0.0920 - accuracy: 0.9659 - val_loss: 0.4636 - val_accuracy: 0.8591
# Epoch 10/44
# 60/60 [==============================] - 2s 30ms/step - loss: 0.1013 - accuracy: 0.9609 - val_loss: 0.1758 - val_accuracy: 0.9472
# Epoch 11/44
# 60/60 [==============================] - 2s 30ms/step - loss: 0.0271 - accuracy: 0.9911 - val_loss: 0.2206 - val_accuracy: 0.9556
# Epoch 12/44
# 60/60 [==============================] - 2s 30ms/step - loss: 0.0083 - accuracy: 0.9976 - val_loss: 0.5244 - val_accuracy: 0.9216
# Epoch 13/44
# 60/60 [==============================] - 2s 30ms/step - loss: 0.0729 - accuracy: 0.9738 - val_loss: 0.1747 - val_accuracy: 0.9442
# Epoch 14/44
# 60/60 [==============================] - 2s 31ms/step - loss: 0.0229 - accuracy: 0.9939 - val_loss: 0.3086 - val_accuracy: 0.9408
# Epoch 15/44
# 60/60 [==============================] - 2s 34ms/step - loss: 0.0028 - accuracy: 0.9997 - val_loss: 0.2392 - val_accuracy: 0.9620
# Epoch 16/44
# 60/60 [==============================] - 2s 35ms/step - loss: 0.0014 - accuracy: 0.9998 - val_loss: 0.2303 - val_accuracy: 0.9647
# Epoch 17/44
# 60/60 [==============================] - 2s 30ms/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.3521 - val_accuracy: 0.9506
# Epoch 18/44
# 60/60 [==============================] - 2s 30ms/step - loss: 9.7461e-04 - accuracy: 0.9998 - val_loss: 0.2836 - val_accuracy: 0.9590
# Epoch 19/44
# 60/60 [==============================] - 2s 30ms/step - loss: 7.9571e-04 - accuracy: 0.9997 - val_loss: 0.3530 - val_accuracy: 0.9516
# Epoch 20/44
# 60/60 [==============================] - 2s 30ms/step - loss: 9.2740e-04 - accuracy: 0.9997 - val_loss: 0.2943 - val_accuracy: 0.9586
# Epoch 21/44
# 60/60 [==============================] - 2s 31ms/step - loss: 6.4894e-04 - accuracy: 0.9998 - val_loss: 0.3064 - val_accuracy: 0.9573
# Epoch 22/44
# 60/60 [==============================] - 2s 36ms/step - loss: 0.0010 - accuracy: 0.9998 - val_loss: 0.2518 - val_accuracy: 0.9664
# Epoch 23/44
# 60/60 [==============================] - 2s 37ms/step - loss: 9.5226e-04 - accuracy: 0.9997 - val_loss: 0.4036 - val_accuracy: 0.9495
# Epoch 24/44
# 60/60 [==============================] - 2s 30ms/step - loss: 7.9277e-04 - accuracy: 0.9997 - val_loss: 0.4235 - val_accuracy: 0.9472
# Epoch 25/44
# 60/60 [==============================] - 2s 30ms/step - loss: 6.3778e-04 - accuracy: 0.9998 - val_loss: 0.2992 - val_accuracy: 0.9586
# Epoch 26/44
# 60/60 [==============================] - 2s 31ms/step - loss: 6.7408e-04 - accuracy: 0.9999 - val_loss: 0.2453 - val_accuracy: 0.9674
# Epoch 27/44
# 60/60 [==============================] - 2s 33ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.3808 - val_accuracy: 0.9516
# Epoch 28/44
# 60/60 [==============================] - 2s 30ms/step - loss: 6.0989e-04 - accuracy: 0.9998 - val_loss: 0.4619 - val_accuracy: 0.9445
# Epoch 29/44
# 60/60 [==============================] - 2s 37ms/step - loss: 8.6204e-04 - accuracy: 0.9997 - val_loss: 0.3986 - val_accuracy: 0.9485
# Epoch 30/44
# 60/60 [==============================] - 2s 34ms/step - loss: 7.5365e-04 - accuracy: 0.9998 - val_loss: 0.3909 - val_accuracy: 0.9509
# Epoch 31/44
# 60/60 [==============================] - 2s 33ms/step - loss: 9.3153e-04 - accuracy: 0.9997 - val_loss: 0.3301 - val_accuracy: 0.9586
# Epoch 32/44
# 60/60 [==============================] - 2s 31ms/step - loss: 9.5375e-04 - accuracy: 0.9997 - val_loss: 0.3302 - val_accuracy: 0.9596
# Epoch 33/44
# 60/60 [==============================] - 2s 31ms/step - loss: 7.1974e-04 - accuracy: 0.9998 - val_loss: 0.5150 - val_accuracy: 0.9425
# Epoch 34/44
# 60/60 [==============================] - 2s 31ms/step - loss: 1.2118 - accuracy: 0.7325 - val_loss: 0.5673 - val_accuracy: 0.7504
# Epoch 35/44
# 60/60 [==============================] - 2s 33ms/step - loss: 0.4869 - accuracy: 0.7711 - val_loss: 0.4464 - val_accuracy: 0.8110
# Epoch 36/44
# 60/60 [==============================] - 2s 36ms/step - loss: 0.4215 - accuracy: 0.8148 - val_loss: 0.4092 - val_accuracy: 0.8130
# Epoch 37/44
# 60/60 [==============================] - 2s 34ms/step - loss: 0.3701 - accuracy: 0.8398 - val_loss: 0.3730 - val_accuracy: 0.8322
# Epoch 38/44
# 60/60 [==============================] - 2s 30ms/step - loss: 0.2760 - accuracy: 0.8849 - val_loss: 0.3970 - val_accuracy: 0.8362
# Epoch 39/44
# 60/60 [==============================] - 2s 31ms/step - loss: 0.1846 - accuracy: 0.9254 - val_loss: 0.2057 - val_accuracy: 0.9233
# Epoch 40/44
# 60/60 [==============================] - 2s 31ms/step - loss: 0.1284 - accuracy: 0.9491 - val_loss: 0.2470 - val_accuracy: 0.9119
# Epoch 41/44
# 60/60 [==============================] - 2s 30ms/step - loss: 0.0622 - accuracy: 0.9781 - val_loss: 0.1989 - val_accuracy: 0.9371
# Epoch 42/44
# 60/60 [==============================] - 2s 31ms/step - loss: 0.0776 - accuracy: 0.9727 - val_loss: 0.1848 - val_accuracy: 0.9401
# Epoch 43/44
# 60/60 [==============================] - 2s 37ms/step - loss: 0.0227 - accuracy: 0.9934 - val_loss: 0.1498 - val_accuracy: 0.9630
# Epoch 44/44
# 60/60 [==============================] - 2s 34ms/step - loss: 0.0057 - accuracy: 0.9990 - val_loss: 0.1512 - val_accuracy: 0.9680
# Training Complete

# %%
tf.keras.utils.plot_model(model_softmax, show_shapes=True, rankdir="LR")

# %%
# Visualize the results:

plt.plot(history_BiLSTM_softmax.history['accuracy'])
plt.plot(history_BiLSTM_softmax.history['val_accuracy'])
plt.title('Model accuracy - Activation function - softmax')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

plt.plot(history_BiLSTM_softmax.history['loss'])
plt.plot(history_BiLSTM_softmax.history['val_loss'])
plt.title('Model loss - Activation function - softmax')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper right')
plt.show()

# %%
pred_BiLSTM_softmax = model_softmax.predict(test_data)

binary_predictions_BiLSTM_softmax = []

for i in pred_BiLSTM_softmax:
    if i >= 0.5:
        binary_predictions_BiLSTM_softmax.append(1)
    else:
        binary_predictions_BiLSTM_softmax.append(0)
# Out:
# 93/93 [==============================] - 2s 9ms/step

# %%
# Confusion Matrix
from sklearn.metrics import confusion_matrix

matrix = confusion_matrix(binary_predictions_BiLSTM_softmax, test_labels)
plt.figure(figsize=(5, 5))
ax= plt.subplot()
sns.heatmap(matrix, annot=True, ax = ax, fmt = ".1f")

# labels, title and ticks
ax.set_xlabel('Predicted Labels', size=20)
ax.set_ylabel('True Labels', size=20)
ax.set_title('Confusion Matrix of BiLSTM Model with Activation function - softmax', size=20) 
ax.xaxis.set_ticklabels(['True News','Fake News'], size=15)
ax.yaxis.set_ticklabels(['True News','Fake News'], size=15)
# Out:
# [Text(0, 0.5, 'True News'), Text(0, 1.5, 'Fake News')]

# %%
# Precision, recall, accuracy score and F1 score

from sklearn import metrics
Accuracy_BiLSTM_softmax = metrics.accuracy_score(test_labels, binary_predictions_BiLSTM_softmax)
Precision_BiLSTM_softmax = metrics.precision_score(test_labels, binary_predictions_BiLSTM_softmax)
Sensitivity_recall_BiLSTM_softmax = metrics.recall_score(test_labels, binary_predictions_BiLSTM_softmax)
Specificity_BiLSTM_softmax = metrics.recall_score(test_labels, binary_predictions_BiLSTM_softmax, pos_label=0)
F1_score_BiLSTM_softmax = metrics.f1_score(test_labels, binary_predictions_BiLSTM_softmax)

print("Accuracy of Model - Activation function - softmax =", Accuracy_BiLSTM_softmax)
print("Precision of Model - Activation function - softmax =", Precision_BiLSTM_softmax)
print("Sensitivity_recall of Model - Activation function - softmax) =", Sensitivity_recall_BiLSTM_softmax)
print("Specificity of Model - Activation function - softmax =", Specificity_BiLSTM_softmax)
print("F1_score of Model - Activation function - softmax =", F1_score_BiLSTM_softmax)
# Out:
# Accuracy of Model - Activation function - softmax = 0.9680457450386815
# Precision of Model - Activation function - softmax = 0.9491059147180193
# Sensitivity_recall of Model - Activation function - softmax) = 0.9850107066381156
# Specificity of Model - Activation function - softmax = 0.9529262086513995
# F1_score of Model - Activation function - softmax = 0.9667250437828372

# %%
plt.plot(history_BiLSTM_relu.history['val_accuracy'])
plt.plot(history_BiLSTM_tanh.history['val_accuracy'])
plt.plot(history_BiLSTM_sigmoid.history['val_accuracy'])
plt.plot(history_BiLSTM_softmax.history['val_accuracy'])
plt.title('Accuracy comparision of BiLSTM Models with different Activation Functions')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['ReLu', 'tanh', 'Sigmoid', 'Softmax'], loc='lower right')
plt.show()

# %%
plt.plot(history_BiLSTM_relu.history['val_loss'])
plt.plot(history_BiLSTM_tanh.history['val_loss'])
plt.plot(history_BiLSTM_sigmoid.history['val_loss'])
plt.plot(history_BiLSTM_softmax.history['val_loss'])
plt.title('Loss comparision of BiLSTM Models with different Activation Functions')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['ReLu', 'tanh', 'Sigmoid', 'Softmax'], loc='upper right')
plt.show()
