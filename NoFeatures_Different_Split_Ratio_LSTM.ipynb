# %%
# Connect to Google Drive 
# Upload the dataset to your Google drive so it can be loaded here

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# First we import the required libraries

import tensorflow as tf
import random
import numpy as np
import pandas as pd
import matplotlib.image  as mpimg
import matplotlib.pyplot as plt
import io
import re
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import regularizers
from tensorflow.keras import backend as K 
K.clear_session()

# Check tensorflow version
if float(tf.__version__[0]) < 2.0:
  print('Updating tensorflow')
  # !pip install tensorflow==2.0
else:
  print('Correct version of Tensorflow installed.')
# Out:
# Correct version of Tensorflow installed.

# %%
# import pandas lib as pd
import pandas as pd
 
# read by default 1st sheet of an excel file
df = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/Testing FNH dataset/RandomOverSampler.xlsx', 'Sheet1')
 
print(df)
df = df.fillna(' ')
df.count()
# Out:
#                                                    Title   Len  \
# 0      Psa: ben stiller speaks out against shaken man...   132
# 1      States take back hundreds of thousands of vacc...  7449
# 2      On the brink: 16 hours til shutdown – cnn poll...  1357
# 3      The us is getting a third coronavirus vaccine....  7855
# 4      Coronavirus variant will likely drive a new wa...  3017
# ...                                                  ...   ...
# 14860  Cops, firefighters challenge gainesville's 'od...   446
# 14861  De blasio dodges on high school admissions tes...  3177
# 14862  Defense dept. issues covid "vaccination record...   255
# 14863  Alaska: cheating husband emasculated after wif...   986
# 14864  Woman who drinks 6 cups of coffee per day tryi...   914
#
#                                                  Content  \
# 0      Actor ben stiller urges parents with adult kid...
# 1      Hundreds of thousands of covid-19 vaccine dose...
# 2      a veteran of the shutdown battles of the mid-1...
# 3      The united states is getting a third coronavir...
# 4      we now are aiming to deliver a second hundred ...
# ...                                                  ...
# 14860  Seldon childers of childers law for the city: ...
# 14861  Brooklyn latin school, staten island technical...
# 14862  Tim young  december 3, 2020 the frontrunning v...
# 14863  Rosetta white, 36, was arrested this week afte...
# 14864  Saying she would stop looking at her phone and...
#
#                                                   Source Publishing Date  \
# 0      https://www.theonion.com/psa-ben-stiller-speak...      2011-03-16
# 1      https://www.cnn.com/2021/02/03/health/states-t...      2021-02-04
# 2      https://www.politico.com/tipsheets/huddle/2013...      2013-09-30
# 3      https://www.cnn.com/2021/02/27/health/johnson-...      2021-02-28
# 4      https://www.cnn.com/2021/02/23/health/us-coron...      2021-02-23
# ...                                                  ...             ...
# 14860  https://www.reuters.com/legal/government/cops-...      2021-08-28
# 14861  https://www.politico.com/newsletters/new-york-...      2018-03-16
# 14862  https://conservativedailypost.com/defense-dept...      2020-12-05
# 14863  https://worldnewsdailyreport.com/alaska-cheati...      2019-06-15
# 14864  https://www.theonion.com/woman-who-drinks-6-cu...      2017-04-04
#
#        Label
# 0          1
# 1          0
# 2          0
# 3          0
# 4          0
# ...      ...
# 14860      0
# 14861      0
# 14862      1
# 14863      1
# 14864      1
#
# [14865 rows x 6 columns]
# Title              14865
# Len                14865
# Content            14865
# Source             14865
# Publishing Date    14865
# Label              14865
# dtype: int64

# %%
# Normalize the dataset
def normalize(data):
    normalized = []
    for i in data:
        i = i.lower()
        # get rid of urls
        i = re.sub('https?://\S+|www\.\S+', '', i)
        # get rid of non words and extra spaces
        i = re.sub('\\W', ' ', i)
        i = re.sub('\n', '', i)
        i = re.sub(' +', ' ', i)
        i = re.sub('^ ', '', i)
        i = re.sub(' $', '', i)
        normalized.append(i)
    return normalized

df['Content'] = normalize(df['Content'])

# %%
# Tokenize text

tokenizer = Tokenizer()
tokenizer.fit_on_texts(df['Content'])
word_index = tokenizer.word_index
vocab_size=len(word_index)
print(vocab_size)

# Padding data

sequences = tokenizer.texts_to_sequences(df['Content'])
padded = pad_sequences(sequences, maxlen=500, padding='post', truncating='post')
# Out:
# 90999

# %% [markdown]
# **Split 70:30**

# %%
# Spliting data
split = 0.3
split_n = int(round(len(padded)*(1-split),0))

train_data = padded[:split_n]
train_labels = df['Label'].values[:split_n]
test_data = padded[split_n:]
test_labels = df['Label'].values[split_n:]

print("Train label","/n",train_labels)
print("/nTest label","/n",test_labels)

print(type(train_data))
print(len(train_data))
print(type(train_labels))
print(len(train_labels))
# Out:
# Train label /n [1 0 0 ... 0 1 0]
# /nTest label /n [0 0 1 ... 1 1 1]
# <class 'numpy.ndarray'>
# 10406
# <class 'numpy.ndarray'>
# 10406

# %%
# Import tensor representations for words - GloVe Embedding
# !wget --no-check-certificate \
    https://storage.googleapis.com/laurencemoroney-blog.appspot.com/glove.6B.100d.txt \
    -O /tmp/glove.6B.100d.txt
embeddings_index = {};
with open('/content/drive/MyDrive/Colab Notebooks/glove.6B.100d.txt') as f:
    for line in f:
        values = line.split();
        word = values[0];
        coefs = np.asarray(values[1:], dtype='float32');
        embeddings_index[word] = coefs;
print(len(coefs))

embeddings_matrix = np.zeros((vocab_size+1, 100));
for word, i in word_index.items():
    embedding_vector = embeddings_index.get(word);
    if embedding_vector is not None:
        embeddings_matrix[i] = embedding_vector;
# Out:
# --2023-02-21 04:15:56--  https://storage.googleapis.com/laurencemoroney-blog.appspot.com/glove.6B.100d.txt
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.250.97.128, 142.251.107.128, 74.125.196.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.250.97.128|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2023-02-21 04:15:56 ERROR 404: Not Found.
#
# 100

# %%
# Build the architecture of the RNN model
     
model_7030 = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size+1, 100, weights=[embeddings_matrix], trainable=False),
    #tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Conv1D(64, 5, activation='relu'),
    tf.keras.layers.MaxPooling1D(pool_size=4),
    tf.keras.layers.LSTM(20, return_sequences=True),
    tf.keras.layers.LSTM(20),
    #tf.keras.layers.Dropout(0.2),  
    tf.keras.layers.Dense(512),
    tf.keras.layers.Dropout(0.3),  
    tf.keras.layers.Dense(256),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# %%
model_7030.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
model_7030.summary()

history_7030 = model_7030.fit(train_data, train_labels, epochs=44, batch_size=200, validation_data=[test_data, test_labels])

print("Training Complete")
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, None, 100)         9100000
#
#  conv1d (Conv1D)             (None, None, 64)          32064
#
#  max_pooling1d (MaxPooling1D  (None, None, 64)         0
#  )
#
#  lstm (LSTM)                 (None, None, 20)          6800
#
#  lstm_1 (LSTM)               (None, 20)                3280
#
#  dense (Dense)               (None, 512)               10752
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dense_2 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 9,284,481
# Trainable params: 184,481
# Non-trainable params: 9,100,000
# _________________________________________________________________
# Epoch 1/44
# 53/53 [==============================] - 17s 42ms/step - loss: 0.6281 - accuracy: 0.6545 - val_loss: 0.6271 - val_accuracy: 0.6620
# Epoch 2/44
# 53/53 [==============================] - 1s 23ms/step - loss: 0.5691 - accuracy: 0.7113 - val_loss: 0.5150 - val_accuracy: 0.7634
# Epoch 3/44
# 53/53 [==============================] - 1s 23ms/step - loss: 0.4602 - accuracy: 0.8012 - val_loss: 0.4574 - val_accuracy: 0.7948
# Epoch 4/44
# 53/53 [==============================] - 1s 26ms/step - loss: 0.3953 - accuracy: 0.8376 - val_loss: 0.3600 - val_accuracy: 0.8583
# Epoch 5/44
# 53/53 [==============================] - 1s 26ms/step - loss: 0.3410 - accuracy: 0.8667 - val_loss: 0.3714 - val_accuracy: 0.8464
# Epoch 6/44
# 53/53 [==============================] - 1s 25ms/step - loss: 0.2761 - accuracy: 0.8972 - val_loss: 0.8972 - val_accuracy: 0.6984
# Epoch 7/44
# 53/53 [==============================] - 1s 25ms/step - loss: 0.2700 - accuracy: 0.9032 - val_loss: 0.5523 - val_accuracy: 0.8199
# Epoch 8/44
# 53/53 [==============================] - 1s 23ms/step - loss: 0.2286 - accuracy: 0.9150 - val_loss: 0.2211 - val_accuracy: 0.9217
# Epoch 9/44
# 53/53 [==============================] - 1s 23ms/step - loss: 0.1217 - accuracy: 0.9638 - val_loss: 0.4265 - val_accuracy: 0.8289
# Epoch 10/44
# 53/53 [==============================] - 1s 23ms/step - loss: 0.1602 - accuracy: 0.9447 - val_loss: 0.3792 - val_accuracy: 0.8704
# Epoch 11/44
# 53/53 [==============================] - 2s 29ms/step - loss: 0.1108 - accuracy: 0.9639 - val_loss: 0.1825 - val_accuracy: 0.9475
# Epoch 12/44
# 53/53 [==============================] - 3s 50ms/step - loss: 0.0618 - accuracy: 0.9829 - val_loss: 0.1894 - val_accuracy: 0.9451
# Epoch 13/44
# 53/53 [==============================] - 3s 49ms/step - loss: 0.0733 - accuracy: 0.9775 - val_loss: 0.9329 - val_accuracy: 0.7421
# Epoch 14/44
# 53/53 [==============================] - 1s 28ms/step - loss: 0.3485 - accuracy: 0.8735 - val_loss: 0.7869 - val_accuracy: 0.7026
# Epoch 15/44
# 53/53 [==============================] - 1s 24ms/step - loss: 0.2415 - accuracy: 0.9087 - val_loss: 0.2032 - val_accuracy: 0.9365
# Epoch 16/44
# 53/53 [==============================] - 1s 23ms/step - loss: 0.0646 - accuracy: 0.9816 - val_loss: 0.1797 - val_accuracy: 0.9513
# Epoch 17/44
# 53/53 [==============================] - 1s 23ms/step - loss: 0.0378 - accuracy: 0.9907 - val_loss: 0.1820 - val_accuracy: 0.9556
# Epoch 18/44
# 53/53 [==============================] - 1s 23ms/step - loss: 0.0259 - accuracy: 0.9955 - val_loss: 0.1782 - val_accuracy: 0.9594
# Epoch 19/44
# 53/53 [==============================] - 1s 25ms/step - loss: 0.0243 - accuracy: 0.9952 - val_loss: 0.1806 - val_accuracy: 0.9632
# Epoch 20/44
# 53/53 [==============================] - 1s 25ms/step - loss: 0.0203 - accuracy: 0.9962 - val_loss: 0.2363 - val_accuracy: 0.9525
# Epoch 21/44
# 53/53 [==============================] - 1s 23ms/step - loss: 0.0212 - accuracy: 0.9958 - val_loss: 0.1534 - val_accuracy: 0.9664
# Epoch 22/44
# 53/53 [==============================] - 1s 23ms/step - loss: 0.0201 - accuracy: 0.9963 - val_loss: 0.2349 - val_accuracy: 0.9538
# Epoch 23/44
# 53/53 [==============================] - 1s 27ms/step - loss: 0.0211 - accuracy: 0.9955 - val_loss: 0.2543 - val_accuracy: 0.9455
# Epoch 24/44
# 53/53 [==============================] - 2s 29ms/step - loss: 0.0199 - accuracy: 0.9967 - val_loss: 0.1978 - val_accuracy: 0.9619
# Epoch 25/44
# 53/53 [==============================] - 1s 26ms/step - loss: 0.0147 - accuracy: 0.9979 - val_loss: 0.2028 - val_accuracy: 0.9628
# Epoch 26/44
# 53/53 [==============================] - 1s 23ms/step - loss: 0.0142 - accuracy: 0.9978 - val_loss: 0.2159 - val_accuracy: 0.9585
# Epoch 27/44
# 53/53 [==============================] - 1s 23ms/step - loss: 0.0133 - accuracy: 0.9980 - val_loss: 0.2351 - val_accuracy: 0.9643
# Epoch 28/44
# 53/53 [==============================] - 1s 23ms/step - loss: 0.0135 - accuracy: 0.9978 - val_loss: 0.1919 - val_accuracy: 0.9686
# Epoch 29/44
# 53/53 [==============================] - 1s 23ms/step - loss: 0.0130 - accuracy: 0.9978 - val_loss: 0.1928 - val_accuracy: 0.9688
# Epoch 30/44
# 53/53 [==============================] - 1s 23ms/step - loss: 0.0128 - accuracy: 0.9982 - val_loss: 0.2347 - val_accuracy: 0.9592
# Epoch 31/44
# 53/53 [==============================] - 1s 23ms/step - loss: 0.0124 - accuracy: 0.9982 - val_loss: 0.2100 - val_accuracy: 0.9648
# Epoch 32/44
# 53/53 [==============================] - 1s 23ms/step - loss: 0.0541 - accuracy: 0.9851 - val_loss: 0.4902 - val_accuracy: 0.8713
# Epoch 33/44
# 53/53 [==============================] - 1s 25ms/step - loss: 0.0535 - accuracy: 0.9847 - val_loss: 0.1906 - val_accuracy: 0.9581
# Epoch 34/44
# 53/53 [==============================] - 1s 28ms/step - loss: 0.0158 - accuracy: 0.9971 - val_loss: 0.1788 - val_accuracy: 0.9601
# Epoch 35/44
# 53/53 [==============================] - 2s 29ms/step - loss: 0.0151 - accuracy: 0.9972 - val_loss: 0.2064 - val_accuracy: 0.9596
# Epoch 36/44
# 53/53 [==============================] - 1s 24ms/step - loss: 0.0145 - accuracy: 0.9973 - val_loss: 0.1954 - val_accuracy: 0.9623
# Epoch 37/44
# 53/53 [==============================] - 1s 23ms/step - loss: 0.0234 - accuracy: 0.9938 - val_loss: 0.1536 - val_accuracy: 0.9666
# Epoch 38/44
# 53/53 [==============================] - 1s 25ms/step - loss: 0.0175 - accuracy: 0.9964 - val_loss: 0.2222 - val_accuracy: 0.9599
# Epoch 39/44
# 53/53 [==============================] - 1s 23ms/step - loss: 0.0152 - accuracy: 0.9971 - val_loss: 0.3448 - val_accuracy: 0.9363
# Epoch 40/44
# 53/53 [==============================] - 1s 23ms/step - loss: 0.0126 - accuracy: 0.9979 - val_loss: 0.2315 - val_accuracy: 0.9612
# Epoch 41/44
# 53/53 [==============================] - 1s 23ms/step - loss: 0.0104 - accuracy: 0.9985 - val_loss: 0.2585 - val_accuracy: 0.9556
# Epoch 42/44
# 53/53 [==============================] - 1s 23ms/step - loss: 0.0092 - accuracy: 0.9986 - val_loss: 0.1843 - val_accuracy: 0.9684
# Epoch 43/44
# 53/53 [==============================] - 1s 23ms/step - loss: 0.0100 - accuracy: 0.9985 - val_loss: 0.1705 - val_accuracy: 0.9715
# Epoch 44/44
# 53/53 [==============================] - 1s 28ms/step - loss: 0.0100 - accuracy: 0.9985 - val_loss: 0.2915 - val_accuracy: 0.9574
# Training Complete

# %%
tf.keras.utils.plot_model(model_7030, show_shapes=True, rankdir="LR")

# %%
# Visualize the results:

plt.plot(history_7030.history['accuracy'])
plt.plot(history_7030.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

plt.plot(history_7030.history['loss'])
plt.plot(history_7030.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper right')
plt.show()

# %%
pred_7030 = model_7030.predict(test_data)

binary_predictions_7030 = []

for i in pred_7030:
    if i >= 0.5:
        binary_predictions_7030.append(1)
    else:
        binary_predictions_7030.append(0)
# Out:
# 140/140 [==============================] - 2s 8ms/step

# %%
# Confusion Matrix
from sklearn.metrics import confusion_matrix

matrix = confusion_matrix(binary_predictions_7030, test_labels)
plt.figure(figsize=(5, 5))
ax= plt.subplot()
sns.heatmap(matrix, annot=True, ax = ax, fmt = ".1f")

# labels, title and ticks
ax.set_xlabel('Predicted Labels', size=20)
ax.set_ylabel('True Labels', size=20)
ax.set_title('Confusion Matrix - Hybrid CNN-LSTM Model - Split Ratio 70:30', size=20) 
ax.xaxis.set_ticklabels(['True News','Fake News'], size=15)
ax.yaxis.set_ticklabels(['True News','Fake News'], size=15)
# Out:
# [Text(0, 0.5, 'True News'), Text(0, 1.5, 'Fake News')]

# %%
# Precision, recall, accuracy score and F1 score

from sklearn import metrics
Accuracy_7030 = metrics.accuracy_score(test_labels, binary_predictions_7030)
Precision_7030 = metrics.precision_score(test_labels, binary_predictions_7030)
Sensitivity_recall_7030 = metrics.recall_score(test_labels, binary_predictions_7030)
Specificity_7030 = metrics.recall_score(test_labels, binary_predictions_7030, pos_label=0)
F1_score_7030 = metrics.f1_score(test_labels, binary_predictions_7030)

print("Accuracy of 70:30 Model (Hybrid CNN-LSTM) =", Accuracy_7030)
print("Precision of 70:30 Model (Hybrid CNN-LSTM) =", Precision_7030)
print("Sensitivity_recall of 70:30 Model (Hybrid CNN-LSTM) =", Sensitivity_recall_7030)
print("Specificity of Model 70:30 (Hybrid CNN-LSTM) =", Specificity_7030)
print("F1_score of Model 70:30 (Hybrid CNN-LSTM) =", F1_score_7030)
# Out:
# Accuracy of 70:30 Model (Hybrid CNN-LSTM) = 0.9573895492262839
# Precision of 70:30 Model (Hybrid CNN-LSTM) = 0.9256489221293445
# Sensitivity_recall of 70:30 Model (Hybrid CNN-LSTM) = 0.9901176470588235
# Specificity of Model 70:30 (Hybrid CNN-LSTM) = 0.927592116538132
# F1_score of Model 70:30 (Hybrid CNN-LSTM) = 0.9567985447930877

# %% [markdown]
# **Split 90:10**

# %%
# Spliting data
split = 0.1
split_n = int(round(len(padded)*(1-split),0))

train_data = padded[:split_n]
train_labels = df['Label'].values[:split_n]
test_data = padded[split_n:]
test_labels = df['Label'].values[split_n:]

print("Train label","/n",train_labels)
print("/nTest label","/n",test_labels)

print(type(train_data))
print(len(train_data))
print(type(train_labels))
print(len(train_labels))
# Out:
# Train label /n [1 0 0 ... 0 1 0]
# /nTest label /n [1 1 0 ... 1 1 1]
# <class 'numpy.ndarray'>
# 13378
# <class 'numpy.ndarray'>
# 13378

# %%
# Import tensor representations for words - GloVe Embedding
# !wget --no-check-certificate \
    https://storage.googleapis.com/laurencemoroney-blog.appspot.com/glove.6B.100d.txt \
    -O /tmp/glove.6B.100d.txt
embeddings_index = {};
with open('/content/drive/MyDrive/Colab Notebooks/glove.6B.100d.txt') as f:
    for line in f:
        values = line.split();
        word = values[0];
        coefs = np.asarray(values[1:], dtype='float32');
        embeddings_index[word] = coefs;
print(len(coefs))

embeddings_matrix = np.zeros((vocab_size+1, 100));
for word, i in word_index.items():
    embedding_vector = embeddings_index.get(word);
    if embedding_vector is not None:
        embeddings_matrix[i] = embedding_vector;
# Out:
# --2023-02-21 04:17:41--  https://storage.googleapis.com/laurencemoroney-blog.appspot.com/glove.6B.100d.txt
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.251.107.128, 74.125.196.128, 173.194.210.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.251.107.128|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2023-02-21 04:17:41 ERROR 404: Not Found.
#
# 100

# %%
# Build the architecture of the RNN model
     
model_9010 = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size+1, 100, weights=[embeddings_matrix], trainable=False),
    #tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Conv1D(64, 5, activation='relu'),
    tf.keras.layers.MaxPooling1D(pool_size=4),
    tf.keras.layers.LSTM(20, return_sequences=True),
    tf.keras.layers.LSTM(20),
    #tf.keras.layers.Dropout(0.2),  
    tf.keras.layers.Dense(512),
    tf.keras.layers.Dropout(0.3),  
    tf.keras.layers.Dense(256),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# %%
model_9010.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
model_9010.summary()

history_9010 = model_9010.fit(train_data, train_labels, epochs=44, batch_size=200, validation_data=[test_data, test_labels])

print("Training Complete")
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_5 (Embedding)     (None, None, 100)         9100000
#
#  conv1d_5 (Conv1D)           (None, None, 64)          32064
#
#  max_pooling1d_5 (MaxPooling  (None, None, 64)         0
#  1D)
#
#  lstm_10 (LSTM)              (None, None, 20)          6800
#
#  lstm_11 (LSTM)              (None, 20)                3280
#
#  dense_15 (Dense)            (None, 512)               10752
#
#  dropout_5 (Dropout)         (None, 512)               0
#
#  dense_16 (Dense)            (None, 256)               131328
#
#  dense_17 (Dense)            (None, 1)                 257
#
# =================================================================
# Total params: 9,284,481
# Trainable params: 184,481
# Non-trainable params: 9,100,000
# _________________________________________________________________
# Epoch 1/44
# 60/60 [==============================] - 7s 36ms/step - loss: 0.6025 - accuracy: 0.6731 - val_loss: 0.5635 - val_accuracy: 0.7104
# Epoch 2/44
# 60/60 [==============================] - 1s 22ms/step - loss: 0.4953 - accuracy: 0.7757 - val_loss: 0.4353 - val_accuracy: 0.8231
# Epoch 3/44
# 60/60 [==============================] - 1s 21ms/step - loss: 0.4079 - accuracy: 0.8283 - val_loss: 0.3500 - val_accuracy: 0.8621
# Epoch 4/44
# 60/60 [==============================] - 1s 22ms/step - loss: 0.3424 - accuracy: 0.8630 - val_loss: 0.2875 - val_accuracy: 0.8907
# Epoch 5/44
# 60/60 [==============================] - 1s 21ms/step - loss: 0.2714 - accuracy: 0.8977 - val_loss: 0.2617 - val_accuracy: 0.9001
# Epoch 6/44
# 60/60 [==============================] - 2s 30ms/step - loss: 0.2211 - accuracy: 0.9223 - val_loss: 0.3023 - val_accuracy: 0.8897
# Epoch 7/44
# 60/60 [==============================] - 3s 42ms/step - loss: 0.1932 - accuracy: 0.9308 - val_loss: 0.2091 - val_accuracy: 0.9250
# Epoch 8/44
# 60/60 [==============================] - 2s 33ms/step - loss: 0.1389 - accuracy: 0.9546 - val_loss: 0.2171 - val_accuracy: 0.9290
# Epoch 9/44
# 60/60 [==============================] - 1s 22ms/step - loss: 0.1160 - accuracy: 0.9631 - val_loss: 0.1351 - val_accuracy: 0.9613
# Epoch 10/44
# 60/60 [==============================] - 1s 21ms/step - loss: 0.0635 - accuracy: 0.9849 - val_loss: 0.1481 - val_accuracy: 0.9603
# Epoch 11/44
# 60/60 [==============================] - 1s 21ms/step - loss: 0.1056 - accuracy: 0.9648 - val_loss: 0.1717 - val_accuracy: 0.9516
# Epoch 12/44
# 60/60 [==============================] - 1s 22ms/step - loss: 0.0449 - accuracy: 0.9901 - val_loss: 0.1488 - val_accuracy: 0.9603
# Epoch 13/44
# 60/60 [==============================] - 1s 22ms/step - loss: 0.0415 - accuracy: 0.9908 - val_loss: 0.1296 - val_accuracy: 0.9694
# Epoch 14/44
# 60/60 [==============================] - 1s 22ms/step - loss: 0.0690 - accuracy: 0.9798 - val_loss: 0.1463 - val_accuracy: 0.9586
# Epoch 15/44
# 60/60 [==============================] - 1s 23ms/step - loss: 0.0380 - accuracy: 0.9908 - val_loss: 0.2667 - val_accuracy: 0.9358
# Epoch 16/44
# 60/60 [==============================] - 2s 27ms/step - loss: 0.0339 - accuracy: 0.9923 - val_loss: 0.2104 - val_accuracy: 0.9539
# Epoch 17/44
# 60/60 [==============================] - 2s 25ms/step - loss: 0.0340 - accuracy: 0.9922 - val_loss: 0.3452 - val_accuracy: 0.9095
# Epoch 18/44
# 60/60 [==============================] - 1s 22ms/step - loss: 0.0538 - accuracy: 0.9843 - val_loss: 0.1309 - val_accuracy: 0.9704
# Epoch 19/44
# 60/60 [==============================] - 1s 22ms/step - loss: 0.0317 - accuracy: 0.9926 - val_loss: 0.1694 - val_accuracy: 0.9657
# Epoch 20/44
# 60/60 [==============================] - 1s 22ms/step - loss: 0.0198 - accuracy: 0.9965 - val_loss: 0.2354 - val_accuracy: 0.9522
# Epoch 21/44
# 60/60 [==============================] - 1s 22ms/step - loss: 0.0819 - accuracy: 0.9754 - val_loss: 0.2817 - val_accuracy: 0.9236
# Epoch 22/44
# 60/60 [==============================] - 1s 22ms/step - loss: 0.0572 - accuracy: 0.9847 - val_loss: 0.1716 - val_accuracy: 0.9627
# Epoch 23/44
# 60/60 [==============================] - 1s 25ms/step - loss: 0.0193 - accuracy: 0.9966 - val_loss: 0.1245 - val_accuracy: 0.9741
# Epoch 24/44
# 60/60 [==============================] - 2s 32ms/step - loss: 0.0328 - accuracy: 0.9918 - val_loss: 0.1720 - val_accuracy: 0.9583
# Epoch 25/44
# 60/60 [==============================] - 2s 41ms/step - loss: 0.0325 - accuracy: 0.9911 - val_loss: 0.2567 - val_accuracy: 0.9499
# Epoch 26/44
# 60/60 [==============================] - 1s 24ms/step - loss: 0.0182 - accuracy: 0.9968 - val_loss: 0.2473 - val_accuracy: 0.9499
# Epoch 27/44
# 60/60 [==============================] - 1s 21ms/step - loss: 0.0206 - accuracy: 0.9958 - val_loss: 0.1180 - val_accuracy: 0.9768
# Epoch 28/44
# 60/60 [==============================] - 1s 22ms/step - loss: 0.0151 - accuracy: 0.9972 - val_loss: 0.1964 - val_accuracy: 0.9623
# Epoch 29/44
# 60/60 [==============================] - 1s 22ms/step - loss: 0.0222 - accuracy: 0.9948 - val_loss: 0.1472 - val_accuracy: 0.9674
# Epoch 30/44
# 60/60 [==============================] - 1s 22ms/step - loss: 0.0624 - accuracy: 0.9829 - val_loss: 0.3173 - val_accuracy: 0.9220
# Epoch 31/44
# 60/60 [==============================] - 1s 22ms/step - loss: 0.0181 - accuracy: 0.9962 - val_loss: 0.2907 - val_accuracy: 0.9415
# Epoch 32/44
# 60/60 [==============================] - 1s 22ms/step - loss: 0.0150 - accuracy: 0.9976 - val_loss: 0.1686 - val_accuracy: 0.9640
# Epoch 33/44
# 60/60 [==============================] - 1s 21ms/step - loss: 0.0112 - accuracy: 0.9984 - val_loss: 0.1499 - val_accuracy: 0.9697
# Epoch 34/44
# 60/60 [==============================] - 1s 23ms/step - loss: 0.0114 - accuracy: 0.9980 - val_loss: 0.2209 - val_accuracy: 0.9623
# Epoch 35/44
# 60/60 [==============================] - 1s 24ms/step - loss: 0.0103 - accuracy: 0.9986 - val_loss: 0.1497 - val_accuracy: 0.9731
# Epoch 36/44
# 60/60 [==============================] - 2s 25ms/step - loss: 0.0085 - accuracy: 0.9987 - val_loss: 0.2522 - val_accuracy: 0.9580
# Epoch 37/44
# 60/60 [==============================] - 1s 22ms/step - loss: 0.0094 - accuracy: 0.9987 - val_loss: 0.1378 - val_accuracy: 0.9748
# Epoch 38/44
# 60/60 [==============================] - 1s 22ms/step - loss: 0.0088 - accuracy: 0.9988 - val_loss: 0.1694 - val_accuracy: 0.9717
# Epoch 39/44
# 60/60 [==============================] - 1s 21ms/step - loss: 0.0084 - accuracy: 0.9987 - val_loss: 0.1342 - val_accuracy: 0.9738
# Epoch 40/44
# 60/60 [==============================] - 1s 22ms/step - loss: 0.0091 - accuracy: 0.9988 - val_loss: 0.1758 - val_accuracy: 0.9684
# Epoch 41/44
# 60/60 [==============================] - 1s 21ms/step - loss: 0.0287 - accuracy: 0.9919 - val_loss: 0.2176 - val_accuracy: 0.9489
# Epoch 42/44
# 60/60 [==============================] - 1s 21ms/step - loss: 0.0637 - accuracy: 0.9818 - val_loss: 0.2204 - val_accuracy: 0.9432
# Epoch 43/44
# 60/60 [==============================] - 1s 21ms/step - loss: 0.0480 - accuracy: 0.9862 - val_loss: 0.2557 - val_accuracy: 0.9169
# Epoch 44/44
# 60/60 [==============================] - 1s 23ms/step - loss: 0.0401 - accuracy: 0.9877 - val_loss: 0.2413 - val_accuracy: 0.9458
# Training Complete

# %%
tf.keras.utils.plot_model(model_9010, show_shapes=True, rankdir="LR")

# %%
# Visualize the results:

plt.plot(history_9010.history['accuracy'])
plt.plot(history_9010.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

plt.plot(history_9010.history['loss'])
plt.plot(history_9010.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper right')
plt.show()

# %%
pred_9010 = model_9010.predict(test_data)

binary_predictions_9010 = []

for i in pred_9010:
    if i >= 0.5:
        binary_predictions_9010.append(1)
    else:
        binary_predictions_9010.append(0)
# Out:
# 93/93 [==============================] - 1s 6ms/step

# %%
# Confusion Matrix
from sklearn.metrics import confusion_matrix

matrix = confusion_matrix(binary_predictions_9010, test_labels)
plt.figure(figsize=(5, 5))
ax= plt.subplot()
sns.heatmap(matrix, annot=True, ax = ax, fmt = ".1f")

# labels, title and ticks
ax.set_xlabel('Predicted Labels', size=20)
ax.set_ylabel('True Labels', size=20)
ax.set_title('Confusion Matrix - Traditional CNN-LSTM Model - Split Ratio 90:10', size=20) 
ax.xaxis.set_ticklabels(['True News','Fake News'], size=15)
ax.yaxis.set_ticklabels(['True News','Fake News'], size=15)
# Out:
# [Text(0, 0.5, 'True News'), Text(0, 1.5, 'Fake News')]

# %%
# Precision, recall, accuracy score and F1 score

from sklearn import metrics
Accuracy_9010 = metrics.accuracy_score(test_labels, binary_predictions_9010)
Precision_9010 = metrics.precision_score(test_labels, binary_predictions_9010)
Sensitivity_recall_9010 = metrics.recall_score(test_labels, binary_predictions_9010)
Specificity_9010 = metrics.recall_score(test_labels, binary_predictions_9010, pos_label=0)
F1_score_9010 = metrics.f1_score(test_labels, binary_predictions_9010)

print("Accuracy of 90:10 Model (Hybris CNN-LSTM) =", Accuracy_9010)
print("Precision of 90:10 Model (Hybrid CNN-LSTM) =", Precision_9010)
print("Sensitivity_recall of 90:10 Model (Hybrid CNN-LSTM) =", Sensitivity_recall_9010)
print("Specificity of Model 90:10 (Hybrid CNN-LSTM) =", Specificity_9010)
print("F1_score of Model 90:10 (Hybrid CNN-LSTM) =", F1_score_9010)
# Out:
# Accuracy of 90:10 Model (Hybris CNN-LSTM) = 0.9458459468550285
# Precision of 90:10 Model (Hybrid CNN-LSTM) = 0.9025974025974026
# Sensitivity_recall of 90:10 Model (Hybrid CNN-LSTM) = 0.9921484653818701
# Specificity of Model 90:10 (Hybrid CNN-LSTM) = 0.9045801526717557
# F1_score of Model 90:10 (Hybrid CNN-LSTM) = 0.9452567154029241

# %% [markdown]
# **Split Ratio 80:20**

# %%
# Spliting data
split = 0.2
split_n = int(round(len(padded)*(1-split),0))

train_data = padded[:split_n]
train_labels = df['Label'].values[:split_n]
test_data = padded[split_n:]
test_labels = df['Label'].values[split_n:]

print("Train label","/n",train_labels)
print("/nTest label","/n",test_labels)

print(type(train_data))
print(len(train_data))
print(type(train_labels))
print(len(train_labels))
# Out:
# Train label /n [1 0 0 ... 1 0 1]
# /nTest label /n [1 1 1 ... 1 1 1]
# <class 'numpy.ndarray'>
# 11892
# <class 'numpy.ndarray'>
# 11892

# %%
# Import tensor representations for words - GloVe Embedding
# !wget --no-check-certificate \
    https://storage.googleapis.com/laurencemoroney-blog.appspot.com/glove.6B.100d.txt \
    -O /tmp/glove.6B.100d.txt
embeddings_index = {};
with open('/content/drive/MyDrive/Colab Notebooks/glove.6B.100d.txt') as f:
    for line in f:
        values = line.split();
        word = values[0];
        coefs = np.asarray(values[1:], dtype='float32');
        embeddings_index[word] = coefs;
print(len(coefs))

embeddings_matrix = np.zeros((vocab_size+1, 100));
for word, i in word_index.items():
    embedding_vector = embeddings_index.get(word);
    if embedding_vector is not None:
        embeddings_matrix[i] = embedding_vector;
# Out:
# --2023-02-21 04:25:59--  https://storage.googleapis.com/laurencemoroney-blog.appspot.com/glove.6B.100d.txt
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.196.128, 173.194.214.128, 173.194.212.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.196.128|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2023-02-21 04:25:59 ERROR 404: Not Found.
#
# 100

# %%
# Build the architecture of the RNN model
     
model_8020 = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size+1, 100, weights=[embeddings_matrix], trainable=False),
    #tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Conv1D(64, 5, activation='relu'),
    tf.keras.layers.MaxPooling1D(pool_size=4),
    tf.keras.layers.LSTM(20, return_sequences=True),
    tf.keras.layers.LSTM(20),
    #tf.keras.layers.Dropout(0.2),  
    tf.keras.layers.Dense(512),
    tf.keras.layers.Dropout(0.3),  
    tf.keras.layers.Dense(256),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# %%
model_8020.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
model_8020.summary()

history_8020 = model_8020.fit(train_data, train_labels, epochs=44, batch_size=200, validation_data=[test_data, test_labels])

print("Training Complete")
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_6 (Embedding)     (None, None, 100)         9100000
#
#  conv1d_6 (Conv1D)           (None, None, 64)          32064
#
#  max_pooling1d_6 (MaxPooling  (None, None, 64)         0
#  1D)
#
#  lstm_12 (LSTM)              (None, None, 20)          6800
#
#  lstm_13 (LSTM)              (None, 20)                3280
#
#  dense_18 (Dense)            (None, 512)               10752
#
#  dropout_6 (Dropout)         (None, 512)               0
#
#  dense_19 (Dense)            (None, 256)               131328
#
#  dense_20 (Dense)            (None, 1)                 257
#
# =================================================================
# Total params: 9,284,481
# Trainable params: 184,481
# Non-trainable params: 9,100,000
# _________________________________________________________________
# Epoch 1/44
# 60/60 [==============================] - 7s 38ms/step - loss: 0.0147 - accuracy: 0.9951 - val_loss: 0.2366 - val_accuracy: 0.9543
# Epoch 2/44
# 60/60 [==============================] - 1s 25ms/step - loss: 0.0036 - accuracy: 0.9996 - val_loss: 0.2104 - val_accuracy: 0.9640
# Epoch 3/44
# 60/60 [==============================] - 1s 24ms/step - loss: 0.0036 - accuracy: 0.9994 - val_loss: 0.2642 - val_accuracy: 0.9623
# Epoch 4/44
# 60/60 [==============================] - 1s 22ms/step - loss: 0.0346 - accuracy: 0.9911 - val_loss: 0.1993 - val_accuracy: 0.9539
# Epoch 5/44
# 60/60 [==============================] - 1s 21ms/step - loss: 0.0434 - accuracy: 0.9839 - val_loss: 0.3598 - val_accuracy: 0.9364
# Epoch 6/44
# 60/60 [==============================] - 1s 21ms/step - loss: 0.0133 - accuracy: 0.9963 - val_loss: 0.2068 - val_accuracy: 0.9630
# Epoch 7/44
# 60/60 [==============================] - 1s 21ms/step - loss: 0.0032 - accuracy: 0.9994 - val_loss: 0.1921 - val_accuracy: 0.9677
# Epoch 8/44
# 60/60 [==============================] - 1s 21ms/step - loss: 0.0029 - accuracy: 0.9996 - val_loss: 0.1991 - val_accuracy: 0.9667
# Epoch 9/44
# 60/60 [==============================] - 1s 21ms/step - loss: 0.0027 - accuracy: 0.9996 - val_loss: 0.1940 - val_accuracy: 0.9667
# Epoch 10/44
# 60/60 [==============================] - 1s 21ms/step - loss: 0.0027 - accuracy: 0.9996 - val_loss: 0.2009 - val_accuracy: 0.9664
# Epoch 11/44
# 60/60 [==============================] - 1s 21ms/step - loss: 0.0029 - accuracy: 0.9996 - val_loss: 0.1905 - val_accuracy: 0.9664
# Epoch 12/44
# 60/60 [==============================] - 1s 24ms/step - loss: 0.0027 - accuracy: 0.9996 - val_loss: 0.2125 - val_accuracy: 0.9667
# Epoch 13/44
# 60/60 [==============================] - 2s 25ms/step - loss: 0.0028 - accuracy: 0.9996 - val_loss: 0.1999 - val_accuracy: 0.9660
# Epoch 14/44
# 60/60 [==============================] - 1s 22ms/step - loss: 0.0028 - accuracy: 0.9996 - val_loss: 0.1930 - val_accuracy: 0.9660
# Epoch 15/44
# 60/60 [==============================] - 1s 21ms/step - loss: 0.0027 - accuracy: 0.9996 - val_loss: 0.1945 - val_accuracy: 0.9660
# Epoch 16/44
# 60/60 [==============================] - 1s 22ms/step - loss: 0.0028 - accuracy: 0.9996 - val_loss: 0.2168 - val_accuracy: 0.9657
# Epoch 17/44
# 60/60 [==============================] - 1s 21ms/step - loss: 0.0028 - accuracy: 0.9996 - val_loss: 0.1931 - val_accuracy: 0.9657
# Epoch 18/44
# 60/60 [==============================] - 1s 22ms/step - loss: 0.0030 - accuracy: 0.9996 - val_loss: 0.1870 - val_accuracy: 0.9657
# Epoch 19/44
# 60/60 [==============================] - 1s 22ms/step - loss: 0.0029 - accuracy: 0.9996 - val_loss: 0.2132 - val_accuracy: 0.9660
# Epoch 20/44
# 60/60 [==============================] - 2s 25ms/step - loss: 0.0028 - accuracy: 0.9996 - val_loss: 0.1881 - val_accuracy: 0.9667
# Epoch 21/44
# 60/60 [==============================] - 2s 25ms/step - loss: 0.0029 - accuracy: 0.9996 - val_loss: 0.2063 - val_accuracy: 0.9664
# Epoch 22/44
# 60/60 [==============================] - 2s 28ms/step - loss: 0.0028 - accuracy: 0.9996 - val_loss: 0.2193 - val_accuracy: 0.9640
# Epoch 23/44
# 60/60 [==============================] - 2s 27ms/step - loss: 0.0027 - accuracy: 0.9996 - val_loss: 0.2092 - val_accuracy: 0.9660
# Epoch 24/44
# 60/60 [==============================] - 1s 24ms/step - loss: 0.0028 - accuracy: 0.9996 - val_loss: 0.2147 - val_accuracy: 0.9657
# Epoch 25/44
# 60/60 [==============================] - 1s 22ms/step - loss: 0.0028 - accuracy: 0.9996 - val_loss: 0.2206 - val_accuracy: 0.9654
# Epoch 26/44
# 60/60 [==============================] - 1s 22ms/step - loss: 0.0027 - accuracy: 0.9996 - val_loss: 0.2340 - val_accuracy: 0.9670
# Epoch 27/44
# 60/60 [==============================] - 1s 21ms/step - loss: 0.0029 - accuracy: 0.9996 - val_loss: 0.1905 - val_accuracy: 0.9670
# Epoch 28/44
# 60/60 [==============================] - 1s 22ms/step - loss: 0.0028 - accuracy: 0.9996 - val_loss: 0.2123 - val_accuracy: 0.9684
# Epoch 29/44
# 60/60 [==============================] - 1s 21ms/step - loss: 0.0029 - accuracy: 0.9996 - val_loss: 0.2375 - val_accuracy: 0.9664
# Epoch 30/44
# 60/60 [==============================] - 1s 21ms/step - loss: 0.0030 - accuracy: 0.9996 - val_loss: 0.2417 - val_accuracy: 0.9660
# Epoch 31/44
# 60/60 [==============================] - 1s 21ms/step - loss: 0.0028 - accuracy: 0.9996 - val_loss: 0.2118 - val_accuracy: 0.9657
# Epoch 32/44
# 60/60 [==============================] - 1s 23ms/step - loss: 0.0028 - accuracy: 0.9996 - val_loss: 0.1947 - val_accuracy: 0.9654
# Epoch 33/44
# 60/60 [==============================] - 1s 24ms/step - loss: 0.0028 - accuracy: 0.9996 - val_loss: 0.1932 - val_accuracy: 0.9717
# Epoch 34/44
# 60/60 [==============================] - 1s 24ms/step - loss: 0.0028 - accuracy: 0.9996 - val_loss: 0.2299 - val_accuracy: 0.9684
# Epoch 35/44
# 60/60 [==============================] - 1s 21ms/step - loss: 0.0030 - accuracy: 0.9996 - val_loss: 0.2188 - val_accuracy: 0.9677
# Epoch 36/44
# 60/60 [==============================] - 1s 22ms/step - loss: 0.0029 - accuracy: 0.9996 - val_loss: 0.2087 - val_accuracy: 0.9674
# Epoch 37/44
# 60/60 [==============================] - 1s 21ms/step - loss: 0.0028 - accuracy: 0.9996 - val_loss: 0.1889 - val_accuracy: 0.9667
# Epoch 38/44
# 60/60 [==============================] - 1s 21ms/step - loss: 0.0028 - accuracy: 0.9996 - val_loss: 0.1966 - val_accuracy: 0.9677
# Epoch 39/44
# 60/60 [==============================] - 1s 22ms/step - loss: 0.0030 - accuracy: 0.9996 - val_loss: 0.2156 - val_accuracy: 0.9650
# Epoch 40/44
# 60/60 [==============================] - 1s 21ms/step - loss: 0.0028 - accuracy: 0.9996 - val_loss: 0.2379 - val_accuracy: 0.9647
# Epoch 41/44
# 60/60 [==============================] - 1s 22ms/step - loss: 0.0028 - accuracy: 0.9996 - val_loss: 0.2444 - val_accuracy: 0.9664
# Epoch 42/44
# 60/60 [==============================] - 1s 23ms/step - loss: 0.0032 - accuracy: 0.9996 - val_loss: 0.2159 - val_accuracy: 0.9637
# Epoch 43/44
# 60/60 [==============================] - 1s 25ms/step - loss: 0.0030 - accuracy: 0.9996 - val_loss: 0.1910 - val_accuracy: 0.9654
# Epoch 44/44
# 60/60 [==============================] - 2s 25ms/step - loss: 0.0030 - accuracy: 0.9996 - val_loss: 0.2213 - val_accuracy: 0.9657
# Training Complete

# %%
tf.keras.utils.plot_model(model_8020, show_shapes=True, rankdir="LR")

# %%
# Visualize the results:

plt.plot(history_8020.history['accuracy'])
plt.plot(history_8020.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

plt.plot(history_8020.history['loss'])
plt.plot(history_8020.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper right')
plt.show()

# %%
pred_8020 = model_8020.predict(test_data)

binary_predictions_8020 = []

for i in pred_8020:
    if i >= 0.5:
        binary_predictions_8020.append(1)
    else:
        binary_predictions_8020.append(0)
# Out:
# 93/93 [==============================] - 1s 6ms/step

# %%
# Confusion Matrix
from sklearn.metrics import confusion_matrix

matrix = confusion_matrix(binary_predictions_8020, test_labels)
plt.figure(figsize=(5, 5))
ax= plt.subplot()
sns.heatmap(matrix, annot=True, ax = ax, fmt = ".1f")

# labels, title and ticks
ax.set_xlabel('Predicted Labels', size=20)
ax.set_ylabel('True Labels', size=20)
ax.set_title('Confusion Matrix - Traditional Hybrid CNN-LSTM Model - Split Ratio 80:20', size=20) 
ax.xaxis.set_ticklabels(['True News','Fake News'], size=15)
ax.yaxis.set_ticklabels(['True News','Fake News'], size=15)
# Out:
# [Text(0, 0.5, 'True News'), Text(0, 1.5, 'Fake News')]

# %%
# Precision, recall, accuracy score and F1 score

from sklearn import metrics
Accuracy_8020 = metrics.accuracy_score(test_labels, binary_predictions_8020)
Precision_8020 = metrics.precision_score(test_labels, binary_predictions_8020)
Sensitivity_recall_8020 = metrics.recall_score(test_labels, binary_predictions_8020)
Specificity_8020 = metrics.recall_score(test_labels, binary_predictions_8020, pos_label=0)
F1_score_8020 = metrics.f1_score(test_labels, binary_predictions_8020)

print("Accuracy of 80:20 Model (Hybrid CNN-LSTM) =", Accuracy_8020)
print("Precision of 80:20 Model (Hybrid CNN-LSTM) =", Precision_8020)
print("Sensitivity_recall of 80:20 Model (Hybrid CNN-LSTM) =", Sensitivity_recall_8020)
print("Specificity of Model 80:20 (Hybrid CNN-LSTM) =", Specificity_8020)
print("F1_score of Model 80:20 (Hybrid CNN-LSTM) =", F1_score_8020)
# Out:
# Accuracy of 80:20 Model (Hybrid CNN-LSTM) = 0.9656912209889001
# Precision of 80:20 Model (Hybrid CNN-LSTM) = 0.939742721733243
# Sensitivity_recall of 80:20 Model (Hybrid CNN-LSTM) = 0.9907209136331192
# Specificity of Model 80:20 (Hybrid CNN-LSTM) = 0.943384223918575
# F1_score of Model 80:20 (Hybrid CNN-LSTM) = 0.9645587213342599

# %% [markdown]
# # **Comparision of Models**

# %%
# Accuracy comparision

plt.plot(history_9010.history['val_accuracy'])
plt.plot(history_8020.history['val_accuracy'])
plt.plot(history_7030.history['val_accuracy'])

plt.title('Comparision of Model accuracy of Traditional Hybrid CNN-LSTM Models')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Split Ratio: 90-10', 'Split Ratio: 80-20', 'Split Ratio: 70-30'], loc='upper left')
plt.show()

# %%
# Loss Comparision
plt.plot(history_9010.history['val_loss'])
plt.plot(history_8020.history['val_loss'])
plt.plot(history_7030.history['val_loss'])

plt.title('Comparision of Model loss of Traditional Hybrid CNN-LSTM Models')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Split Ratio: 90-10', 'Split Ratio: 80-20', 'Split Ratio: 70-30'], loc='upper left')
plt.show()
