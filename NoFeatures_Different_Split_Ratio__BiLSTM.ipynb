# %%
# Connect to Google Drive 
# Upload the dataset to your Google drive so it can be loaded here

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# First we import the required libraries

import tensorflow as tf
import random
import numpy as np
import pandas as pd
import matplotlib.image  as mpimg
import matplotlib.pyplot as plt
import io
import re
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import regularizers
from tensorflow.keras import backend as K 
K.clear_session()

# Check tensorflow version
if float(tf.__version__[0]) < 2.0:
  print('Updating tensorflow')
  # !pip install tensorflow==2.0
else:
  print('Correct version of Tensorflow installed.')
# Out:
# Correct version of Tensorflow installed.

# %%
# import pandas lib as pd
import pandas as pd
 
# read by default 1st sheet of an excel file
df = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/Testing FNH dataset/RandomOverSampler.xlsx', 'Sheet1')
 
print(df)
df = df.fillna(' ')
df.count()
# Out:
#                                                    Title   Len  \
# 0      Psa: ben stiller speaks out against shaken man...   132
# 1      States take back hundreds of thousands of vacc...  7449
# 2      On the brink: 16 hours til shutdown – cnn poll...  1357
# 3      The us is getting a third coronavirus vaccine....  7855
# 4      Coronavirus variant will likely drive a new wa...  3017
# ...                                                  ...   ...
# 14860  Cops, firefighters challenge gainesville's 'od...   446
# 14861  De blasio dodges on high school admissions tes...  3177
# 14862  Defense dept. issues covid "vaccination record...   255
# 14863  Alaska: cheating husband emasculated after wif...   986
# 14864  Woman who drinks 6 cups of coffee per day tryi...   914
#
#                                                  Content  \
# 0      Actor ben stiller urges parents with adult kid...
# 1      Hundreds of thousands of covid-19 vaccine dose...
# 2      a veteran of the shutdown battles of the mid-1...
# 3      The united states is getting a third coronavir...
# 4      we now are aiming to deliver a second hundred ...
# ...                                                  ...
# 14860  Seldon childers of childers law for the city: ...
# 14861  Brooklyn latin school, staten island technical...
# 14862  Tim young  december 3, 2020 the frontrunning v...
# 14863  Rosetta white, 36, was arrested this week afte...
# 14864  Saying she would stop looking at her phone and...
#
#                                                   Source Publishing Date  \
# 0      https://www.theonion.com/psa-ben-stiller-speak...      2011-03-16
# 1      https://www.cnn.com/2021/02/03/health/states-t...      2021-02-04
# 2      https://www.politico.com/tipsheets/huddle/2013...      2013-09-30
# 3      https://www.cnn.com/2021/02/27/health/johnson-...      2021-02-28
# 4      https://www.cnn.com/2021/02/23/health/us-coron...      2021-02-23
# ...                                                  ...             ...
# 14860  https://www.reuters.com/legal/government/cops-...      2021-08-28
# 14861  https://www.politico.com/newsletters/new-york-...      2018-03-16
# 14862  https://conservativedailypost.com/defense-dept...      2020-12-05
# 14863  https://worldnewsdailyreport.com/alaska-cheati...      2019-06-15
# 14864  https://www.theonion.com/woman-who-drinks-6-cu...      2017-04-04
#
#        Label
# 0          1
# 1          0
# 2          0
# 3          0
# 4          0
# ...      ...
# 14860      0
# 14861      0
# 14862      1
# 14863      1
# 14864      1
#
# [14865 rows x 6 columns]
# Title              14865
# Len                14865
# Content            14865
# Source             14865
# Publishing Date    14865
# Label              14865
# dtype: int64

# %%
# Normalize the dataset
def normalize(data):
    normalized = []
    for i in data:
        i = i.lower()
        # get rid of urls
        i = re.sub('https?://\S+|www\.\S+', '', i)
        # get rid of non words and extra spaces
        i = re.sub('\\W', ' ', i)
        i = re.sub('\n', '', i)
        i = re.sub(' +', ' ', i)
        i = re.sub('^ ', '', i)
        i = re.sub(' $', '', i)
        normalized.append(i)
    return normalized

df['Content'] = normalize(df['Content'])

# %%
# Tokenize text

tokenizer = Tokenizer()
tokenizer.fit_on_texts(df['Content'])
word_index = tokenizer.word_index
vocab_size=len(word_index)
print(vocab_size)

# Padding data

sequences = tokenizer.texts_to_sequences(df['Content'])
padded = pad_sequences(sequences, maxlen=500, padding='post', truncating='post')
# Out:
# 90999

# %% [markdown]
# **Split 70:30**

# %%
# Spliting data
split = 0.3
split_n = int(round(len(padded)*(1-split),0))

train_data = padded[:split_n]
train_labels = df['Label'].values[:split_n]
test_data = padded[split_n:]
test_labels = df['Label'].values[split_n:]

print("Train label","/n",train_labels)
print("/nTest label","/n",test_labels)

print(type(train_data))
print(len(train_data))
print(type(train_labels))
print(len(train_labels))
# Out:
# Train label /n [1 0 0 ... 0 1 0]
# /nTest label /n [0 0 1 ... 1 1 1]
# <class 'numpy.ndarray'>
# 10406
# <class 'numpy.ndarray'>
# 10406

# %%
# Import tensor representations for words - GloVe Embedding
# !wget --no-check-certificate \
    https://storage.googleapis.com/laurencemoroney-blog.appspot.com/glove.6B.100d.txt \
    -O /tmp/glove.6B.100d.txt
embeddings_index = {};
with open('/content/drive/MyDrive/Colab Notebooks/glove.6B.100d.txt') as f:
    for line in f:
        values = line.split();
        word = values[0];
        coefs = np.asarray(values[1:], dtype='float32');
        embeddings_index[word] = coefs;
print(len(coefs))

embeddings_matrix = np.zeros((vocab_size+1, 100));
for word, i in word_index.items():
    embedding_vector = embeddings_index.get(word);
    if embedding_vector is not None:
        embeddings_matrix[i] = embedding_vector;
# Out:
# --2023-02-24 04:31:25--  https://storage.googleapis.com/laurencemoroney-blog.appspot.com/glove.6B.100d.txt
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.200.128, 74.125.68.128, 74.125.24.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.200.128|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2023-02-24 04:31:26 ERROR 404: Not Found.
#
# 100

# %%
# Build the architecture of the RNN model
     
model_BiLSTM_7030 = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size+1, 100, weights=[embeddings_matrix], trainable=False),
    #tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Conv1D(64, 5, activation='softmax'),
    tf.keras.layers.MaxPooling1D(pool_size=4),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(20,  return_sequences=True)),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(20)),
    #tf.keras.layers.Dropout(0.2),  
    tf.keras.layers.Dense(512),
    tf.keras.layers.Dropout(0.3),  
    tf.keras.layers.Dense(256),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# %%
model_BiLSTM_7030.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
model_BiLSTM_7030.summary()

history_BiLSTM_7030 = model_BiLSTM_7030.fit(train_data, train_labels, epochs=44, batch_size=200, validation_data=[test_data, test_labels])

print("Training Complete")
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, None, 100)         9100000
#
#  conv1d (Conv1D)             (None, None, 64)          32064
#
#  max_pooling1d (MaxPooling1D  (None, None, 64)         0
#  )
#
#  bidirectional (Bidirectiona  (None, None, 40)         13600
#  l)
#
#  bidirectional_1 (Bidirectio  (None, 40)               9760
#  nal)
#
#  dense (Dense)               (None, 512)               20992
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dense_2 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 9,308,001
# Trainable params: 208,001
# Non-trainable params: 9,100,000
# _________________________________________________________________
# Epoch 1/44
# 53/53 [==============================] - 21s 63ms/step - loss: 0.6249 - accuracy: 0.6557 - val_loss: 0.6644 - val_accuracy: 0.6614
# Epoch 2/44
# 53/53 [==============================] - 2s 34ms/step - loss: 0.5618 - accuracy: 0.7207 - val_loss: 0.5163 - val_accuracy: 0.7383
# Epoch 3/44
# 53/53 [==============================] - 2s 35ms/step - loss: 0.4805 - accuracy: 0.7734 - val_loss: 0.4745 - val_accuracy: 0.7988
# Epoch 4/44
# 53/53 [==============================] - 2s 39ms/step - loss: 0.4298 - accuracy: 0.8027 - val_loss: 0.4334 - val_accuracy: 0.7959
# Epoch 5/44
# 53/53 [==============================] - 2s 41ms/step - loss: 0.3908 - accuracy: 0.8274 - val_loss: 0.3778 - val_accuracy: 0.8325
# Epoch 6/44
# 53/53 [==============================] - 2s 34ms/step - loss: 0.3196 - accuracy: 0.8638 - val_loss: 0.3558 - val_accuracy: 0.8457
# Epoch 7/44
# 53/53 [==============================] - 2s 34ms/step - loss: 0.2603 - accuracy: 0.8908 - val_loss: 0.2984 - val_accuracy: 0.8697
# Epoch 8/44
# 53/53 [==============================] - 2s 33ms/step - loss: 0.1795 - accuracy: 0.9288 - val_loss: 0.2653 - val_accuracy: 0.8977
# Epoch 9/44
# 53/53 [==============================] - 2s 34ms/step - loss: 0
# Epoch 38/44
# 53/53 [==============================] - 2s 34ms/step - loss: 7.8943e-04 - accuracy: 0.9998 - val_loss: 0.5049 - val_accuracy: 0.9527
# Epoch 39/44
# 53/53 [==============================] - 2s 34ms/step - loss: 5.4090e-04 - accuracy: 0.9998 - val_loss: 0.4909 - val_accuracy: 0.9522
# Epoch 40/44
# 53/53 [==============================] - 2s 37ms/step - loss: 8.0651e-04 - accuracy: 0.9997 - val_loss: 0.4805 - val_accuracy: 0.9549
# Epoch 41/44
# 53/53 [==============================] - 2s 40ms/step - loss: 7.5122e-04 - accuracy: 0.9996 - val_loss: 0.4940 - val_accuracy: 0.9518
# Epoch 42/44
# 53/53 [==============================] - 2s 34ms/step - loss: 6.3838e-04 - accuracy: 0.9998 - val_loss: 0.5277 - val_accuracy: 0.9500
# Epoch 43/44
# 53/53 [==============================] - 2s 33ms/step - loss: 8.7926e-04 - accuracy: 0.9998 - val_loss: 0.4534 - val_accuracy: 0.9563
# Epoch 44/44
# 53/53 [==============================] - 2s 34ms/step - loss: 0.0010 - accuracy: 0.9996 - val_loss: 0.3554 - val_accuracy: 0.9657
# Training Complete

# %%
tf.keras.utils.plot_model(model_BiLSTM_7030, show_shapes=True, rankdir="LR")

# %%
# Visualize the results:

plt.plot(history_BiLSTM_7030.history['accuracy'])
plt.plot(history_BiLSTM_7030.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

plt.plot(history_BiLSTM_7030.history['loss'])
plt.plot(history_BiLSTM_7030.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper right')
plt.show()

# %%
pred_BiLSTM_7030 = model_BiLSTM_7030.predict(test_data)

binary_predictions_BiLSTM_7030 = []

for i in pred_BiLSTM_7030:
    if i >= 0.5:
        binary_predictions_BiLSTM_7030.append(1)
    else:
        binary_predictions_BiLSTM_7030.append(0)
# Out:
# 140/140 [==============================] - 3s 9ms/step

# %%
# Confusion Matrix
from sklearn.metrics import confusion_matrix

matrix = confusion_matrix(binary_predictions_BiLSTM_7030, test_labels)
plt.figure(figsize=(5, 5))
ax= plt.subplot()
sns.heatmap(matrix, annot=True, ax = ax, fmt = ".1f")

# labels, title and ticks
ax.set_xlabel('Predicted Labels', size=20)
ax.set_ylabel('True Labels', size=20)
ax.set_title('Confusion Matrix - Traditional Hybrid CNN-BiLSTM with Split Ratio 70:30', size=20) 
ax.xaxis.set_ticklabels(['True News','Fake News'], size=15)
ax.yaxis.set_ticklabels(['True News','Fake News'], size=15)
# Out:
# [Text(0, 0.5, 'True News'), Text(0, 1.5, 'Fake News')]

# %%
# Precision, recall, accuracy score and F1 score

from sklearn import metrics
Accuracy_7030 = metrics.accuracy_score(test_labels, binary_predictions_BiLSTM_7030)
Precision_7030 = metrics.precision_score(test_labels, binary_predictions_BiLSTM_7030)
Sensitivity_recall_7030 = metrics.recall_score(test_labels, binary_predictions_BiLSTM_7030)
Specificity_7030 = metrics.recall_score(test_labels, binary_predictions_BiLSTM_7030, pos_label=0)
F1_score_7030 = metrics.f1_score(test_labels, binary_predictions_BiLSTM_7030)

print("Accuracy of 70:30 BiLSTM Model =", Accuracy_7030)
print("Precision of 70:30 BiLSTM Model =", Precision_7030)
print("Sensitivity_recall of 70:30 BiLSTM Model =", Sensitivity_recall_7030)
print("Specificity of BiLSTM Model 70:30 =", Specificity_7030)
print("F1_score of BiLSTM Model 70:30 =", F1_score_7030)
# Out:
# Accuracy of 70:30 BiLSTM Model = 0.9656873738506392
# Precision of 70:30 BiLSTM Model = 0.9429469901168014
# Sensitivity_recall of 70:30 BiLSTM Model = 0.987764705882353
# Specificity of BiLSTM Model 70:30 = 0.9455869751499572
# F1_score of BiLSTM Model 70:30 = 0.9648356699609285

# %% [markdown]
# **Split 90:10**

# %%
# Spliting data
split = 0.1
split_n = int(round(len(padded)*(1-split),0))

train_data = padded[:split_n]
train_labels = df['Label'].values[:split_n]
test_data = padded[split_n:]
test_labels = df['Label'].values[split_n:]

print("Train label","/n",train_labels)
print("/nTest label","/n",test_labels)

print(type(train_data))
print(len(train_data))
print(type(train_labels))
print(len(train_labels))
# Out:
# Train label /n [1 0 0 ... 0 1 0]
# /nTest label /n [1 1 0 ... 1 1 1]
# <class 'numpy.ndarray'>
# 13378
# <class 'numpy.ndarray'>
# 13378

# %%
# Import tensor representations for words - GloVe Embedding
# !wget --no-check-certificate \
    https://storage.googleapis.com/laurencemoroney-blog.appspot.com/glove.6B.100d.txt \
    -O /tmp/glove.6B.100d.txt
embeddings_index = {};
with open('/content/drive/MyDrive/Colab Notebooks/glove.6B.100d.txt') as f:
    for line in f:
        values = line.split();
        word = values[0];
        coefs = np.asarray(values[1:], dtype='float32');
        embeddings_index[word] = coefs;
print(len(coefs))

embeddings_matrix = np.zeros((vocab_size+1, 100));
for word, i in word_index.items():
    embedding_vector = embeddings_index.get(word);
    if embedding_vector is not None:
        embeddings_matrix[i] = embedding_vector;
# Out:
# --2023-02-24 04:33:30--  https://storage.googleapis.com/laurencemoroney-blog.appspot.com/glove.6B.100d.txt
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.68.128, 74.125.24.128, 142.250.4.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.68.128|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2023-02-24 04:33:31 ERROR 404: Not Found.
#
# 100

# %%
# Build the architecture of the RNN model
     
model_BiLSTM_9010 = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size+1, 100, weights=[embeddings_matrix], trainable=False),
    #tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Conv1D(64, 5, activation='softmax'),
    tf.keras.layers.MaxPooling1D(pool_size=4),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(20,  return_sequences=True)),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(20)),
    #tf.keras.layers.Dropout(0.2),  
    tf.keras.layers.Dense(512),
    tf.keras.layers.Dropout(0.3),  
    tf.keras.layers.Dense(256),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# %%
model_BiLSTM_9010.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
model_BiLSTM_9010.summary()

history_BiLSTM_9010 = model_BiLSTM_9010.fit(train_data, train_labels, epochs=44, batch_size=200, validation_data=[test_data, test_labels])

print("Training Complete")
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, None, 100)         9100000
#
#  conv1d_1 (Conv1D)           (None, None, 64)          32064
#
#  max_pooling1d_1 (MaxPooling  (None, None, 64)         0
#  1D)
#
#  bidirectional_2 (Bidirectio  (None, None, 40)         13600
#  nal)
#
#  bidirectional_3 (Bidirectio  (None, 40)               9760
#  nal)
#
#  dense_3 (Dense)             (None, 512)               20992
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_4 (Dense)             (None, 256)               131328
#
#  dense_5 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 9,308,001
# Trainable params: 208,001
# Non-trainable params: 9,100,000
# _________________________________________________________________
# Epoch 1/44
# 67/67 [==============================] - 12s 54ms/step - loss: 0.5770 - accuracy: 0.6896 - val_loss: 0.4808 - val_accuracy: 0.7767
# Epoch 2/44
# 67/67 [==============================] - 2s 30ms/step - loss: 0.4513 - accuracy: 0.7926 - val_loss: 0.3939 - val_accuracy: 0.8305
# Epoch 3/44
# 67/67 [==============================] - 2s 30ms/step - loss: 0.3696 - accuracy: 0.8386 - val_loss: 0.3511 - val_accuracy: 0.8460
# Epoch 4/44
# 67/67 [==============================] - 2s 36ms/step - loss: 0.3091 - accuracy: 0.8666 - val_loss: 0.3096 - val_accuracy: 0.8783
# Epoch 5/44
# 67/67 [==============================] - 2s 33ms/step - loss: 0.2460 - accuracy: 0.8967 - val_loss: 0.2571 - val_accuracy: 0.8978
# Epoch 6/44
# 67/67 [==============================] - 2s 31ms/step - loss: 0.1861 - accuracy: 0.9251 - val_loss: 0.2214 - val_accuracy: 0.9233
# Epoch 7/44
# 67/67 [==============================] - 2s 30ms/step - loss: 0
44
# 67/67 [==============================] - 2s 30ms/step - loss: 0.1531 - accuracy: 0.9429 - val_loss: 0.3478 - val_accuracy: 0.8803
# Epoch 35/44
# 67/67 [==============================] - 2s 32ms/step - loss: 0.1320 - accuracy: 0.9504 - val_loss: 0.2497 - val_accuracy: 0.9119
# Epoch 36/44
# 67/67 [==============================] - 2s 36ms/step - loss: 0.1021 - accuracy: 0.9605 - val_loss: 0.2223 - val_accuracy: 0.9348
# Epoch 37/44
# 67/67 [==============================] - 2s 31ms/step - loss: 0.0312 - accuracy: 0.9919 - val_loss: 0.1923 - val_accuracy: 0.9570
# Epoch 38/44
# 67/67 [==============================] - 2s 30ms/step - loss: 0.0116 - accuracy: 0.9981 - val_loss: 0.2673 - val_accuracy: 0.9489
# Epoch 39/44
# 67/67 [==============================] - 2s 30ms/step - loss: 0.0096 - accuracy: 0.9987 - val_loss: 0.2710 - val_accuracy: 0.9563
# Epoch 40/44
# 67/67 [==============================] - 2s 30ms/step - loss: 0.0027 - accuracy: 0.9998 - val_loss: 0.2611 - val_accuracy: 0.9617
# Epoch 41/44
# 67/67 [==============================] - 2s 30ms/step - loss: 0.0019 - accuracy: 0.9999 - val_loss: 0.2766 - val_accuracy: 0.9637
# Epoch 42/44
# 67/67 [==============================] - 2s 34ms/step - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.2653 - val_accuracy: 0.9650
# Epoch 43/44
# 67/67 [==============================] - 2s 34ms/step - loss: 0.0010 - accuracy: 0.9999 - val_loss: 0.2632 - val_accuracy: 0.9664
# Epoch 44/44
# 67/67 [==============================] - 2s 30ms/step - loss: 8.2098e-04 - accuracy: 0.9999 - val_loss: 0.2647 - val_accuracy: 0.9670
# Training Complete

# %%
tf.keras.utils.plot_model(model_BiLSTM_9010, show_shapes=True, rankdir="LR")

# %%
# Visualize the results:

plt.plot(history_BiLSTM_9010.history['accuracy'])
plt.plot(history_BiLSTM_9010.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

plt.plot(history_BiLSTM_9010.history['loss'])
plt.plot(history_BiLSTM_9010.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper right')
plt.show()

# %%
pred_9010 = model_BiLSTM_9010.predict(test_data)

binary_predictions_9010 = []

for i in pred_9010:
    if i >= 0.5:
        binary_predictions_9010.append(1)
    else:
        binary_predictions_9010.append(0)
# Out:
# 47/47 [==============================] - 2s 10ms/step

# %%
# Confusion Matrix
from sklearn.metrics import confusion_matrix

matrix = confusion_matrix(binary_predictions_9010, test_labels)
plt.figure(figsize=(5, 5))
ax= plt.subplot()
sns.heatmap(matrix, annot=True, ax = ax, fmt = ".1f")

# labels, title and ticks
ax.set_xlabel('Predicted Labels', size=20)
ax.set_ylabel('True Labels', size=20)
ax.set_title('Confusion Matrix - Traditional Hybrid CNN-BiLSTM with Split Ratio 90:10', size=20) 
ax.xaxis.set_ticklabels(['True News','Fake News'], size=15)
ax.yaxis.set_ticklabels(['True News','Fake News'], size=15)
# Out:
# [Text(0, 0.5, 'True News'), Text(0, 1.5, 'Fake News')]

# %%
# Precision, recall, accuracy score and F1 score

from sklearn import metrics
Accuracy_9010 = metrics.accuracy_score(test_labels, binary_predictions_9010)
Precision_9010 = metrics.precision_score(test_labels, binary_predictions_9010)
Sensitivity_recall_9010 = metrics.recall_score(test_labels, binary_predictions_9010)
Specificity_9010 = metrics.recall_score(test_labels, binary_predictions_9010, pos_label=0)
F1_score_9010 = metrics.f1_score(test_labels, binary_predictions_9010)

print("Accuracy of 90:10 BiLSTM Model =", Accuracy_9010)
print("Precision of 90:10 BiLSTM Model =", Precision_9010)
print("Sensitivity_recall of 90:10 BiLSTM Model =", Sensitivity_recall_9010)
print("Specificity of BiLSTM Model 90:10 =", Specificity_9010)
print("F1_score of BiLSTM Model 90:10 =", F1_score_9010)
# Out:
# Accuracy of 90:10 BiLSTM Model = 0.9670477471418965
# Precision of 90:10 BiLSTM Model = 0.9340511440107672
# Sensitivity_recall of 90:10 BiLSTM Model = 1.0
# Specificity of BiLSTM Model 90:10 = 0.9382093316519546
# F1_score of BiLSTM Model 90:10 = 0.965901183020181

# %% [markdown]
# **Split Ratio 80:20**

# %%
# Spliting data
split = 0.2
split_n = int(round(len(padded)*(1-split),0))

train_data = padded[:split_n]
train_labels = df['Label'].values[:split_n]
test_data = padded[split_n:]
test_labels = df['Label'].values[split_n:]

print("Train label","/n",train_labels)
print("/nTest label","/n",test_labels)

print(type(train_data))
print(len(train_data))
print(type(train_labels))
print(len(train_labels))
# Out:
# Train label /n [1 0 0 ... 1 0 1]
# /nTest label /n [1 1 1 ... 1 1 1]
# <class 'numpy.ndarray'>
# 11892
# <class 'numpy.ndarray'>
# 11892

# %%
# Import tensor representations for words - GloVe Embedding
# !wget --no-check-certificate \
    https://storage.googleapis.com/laurencemoroney-blog.appspot.com/glove.6B.100d.txt \
    -O /tmp/glove.6B.100d.txt
embeddings_index = {};
with open('/content/drive/MyDrive/Colab Notebooks/glove.6B.100d.txt') as f:
    for line in f:
        values = line.split();
        word = values[0];
        coefs = np.asarray(values[1:], dtype='float32');
        embeddings_index[word] = coefs;
print(len(coefs))

embeddings_matrix = np.zeros((vocab_size+1, 100));
for word, i in word_index.items():
    embedding_vector = embeddings_index.get(word);
    if embedding_vector is not None:
        embeddings_matrix[i] = embedding_vector;
# Out:
# --2023-02-24 04:36:13--  https://storage.googleapis.com/laurencemoroney-blog.appspot.com/glove.6B.100d.txt
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.251.10.128, 142.251.12.128, 172.217.194.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.251.10.128|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2023-02-24 04:36:15 ERROR 404: Not Found.
#
# 100

# %%
# Build the architecture of the RNN model
     
model_BiLSTM_8020 = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size+1, 100, weights=[embeddings_matrix], trainable=False),
    #tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Conv1D(64, 5, activation='softmax'),
    tf.keras.layers.MaxPooling1D(pool_size=4),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(20,  return_sequences=True)),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(20)),
    #tf.keras.layers.Dropout(0.2),  
    tf.keras.layers.Dense(512),
    tf.keras.layers.Dropout(0.3),  
    tf.keras.layers.Dense(256),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# %%
model_BiLSTM_8020.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
model_BiLSTM_8020.summary()

history_BiLSTM_8020 = model_BiLSTM_8020.fit(train_data, train_labels, epochs=44, batch_size=200, validation_data=[test_data, test_labels])

print("Training Complete")
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, None, 100)         9100000
#
#  conv1d_2 (Conv1D)           (None, None, 64)          32064
#
#  max_pooling1d_2 (MaxPooling  (None, None, 64)         0
#  1D)
#
#  bidirectional_4 (Bidirectio  (None, None, 40)         13600
#  nal)
#
#  bidirectional_5 (Bidirectio  (None, 40)               9760
#  nal)
#
#  dense_6 (Dense)             (None, 512)               20992
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_7 (Dense)             (None, 256)               131328
#
#  dense_8 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 9,308,001
# Trainable params: 208,001
# Non-trainable params: 9,100,000
# _________________________________________________________________
# Epoch 1/44
# 60/60 [==============================] - 10s 56ms/step - loss: 0.5963 - accuracy: 0.6747 - val_loss: 0.5272 - val_accuracy: 0.7555
# Epoch 2/44
# 60/60 [==============================] - 2s 38ms/step - loss: 0.4811 - accuracy: 0.7740 - val_loss: 0.4310 - val_accuracy: 0.8039
# Epoch 3/44
# 60/60 [==============================] - 2s 34ms/step - loss: 0.4206 - accuracy: 0.8068 - val_loss: 0.3933 - val_accuracy: 0.8261
# Epoch 4/44
# 60/60 [==============================] - 2s 33ms/step - loss: 0.3589 - accuracy: 0.8459 - val_loss: 0.3806 - val_accuracy: 0.8399
# Epoch 5/44
# 60/60 [==============================] - 2s 31ms/step - loss: 0.2942 - accuracy: 0.8792 - val_loss: 0.3056 - val_accuracy: 0.8772
# Epoch 6/44
# 60/60 [==============================] - 2s 31ms/step - loss: 0.2413 - accuracy: 0.9033 - val_loss: 0.4132 - val_accuracy: 0.8157
# Epoch 7/44
# 60/60 [==============================] - 2s 31ms/step - loss: 0.1898 - accuracy: 0.9247 - val_loss: 0.4961 - val_accuracy: 0.7965
# Epoch 8/44
# 60/60 [==============================] - 2s 33ms/step - loss: 0.1712 - accuracy: 0.9283 - val_loss: 0.2097 - val_accuracy: 0.9186
# Epoch 9/44
# 60/60 [==============================] - 2s 40ms/step - loss: 0.1155 - accuracy: 0.9554 - val_loss: 0.1822 - val_accuracy: 0.9462
# Epoch 10/44
# 60/60 [==============================] - 2s 33ms/step - loss: 0.0710 - accuracy: 0.9730 - val_loss: 0.2775 - val_accuracy: 0.8897
# Epoch 11/44
# 60/60 [==============================] - 2s 32ms/step - loss: 0.0391 - accuracy: 0.9874 - val_loss: 0.1957 - val_accuracy: 0.9600
# Epoch 12/44
# 60/60 [==============================] - 2s 31ms/step - loss: 0.1634 - accuracy: 0.9628 - val_loss: 0.4511 - val_accuracy: 0.8466
# Epoch 13/44
# 60/60 [==============================] - 2s 32ms/step - loss: 0.1357 - accuracy: 0.9476 - val_loss: 0.1719 - val_accuracy: 0.9499
# Epoch 14/44
# 60/60 [==============================] - 2s 32ms/step - loss: 0.0343 - accuracy: 0.9887 - val_loss: 0.2237 - val_accuracy: 0.9549
# Epoch 15/44
# 60/60 [==============================] - 2s 37ms/step - loss: 0.0095 - accuracy: 0.9979 - val_loss: 0.2660 - val_accuracy: 0.9549
# Epoch 16/44
# 60/60 [==============================] - 2s 37ms/step - loss: 0.0049 - accuracy: 0.9991 - val_loss: 0.2381 - val_accuracy: 0.9630
# Epoch 17/44
# 60/60 [==============================] - 2s 32ms/step - loss: 0.0036 - accuracy: 0.9992 - val_loss: 0.2065 - val_accuracy: 0.9721
# Epoch 18/44
# 60/60 [==============================] - 2s 32ms/step - loss: 0.0032 - accuracy: 0.9994 - val_loss: 0.2084 - val_accuracy: 0.9748
# Epoch 19/44
# 60/60 [==============================] - 2s 32ms/step - loss: 0.0028 - accuracy: 0.9994 - val_loss: 0.2346 - val_accuracy: 0.9728
# Epoch 20/44
# 60/60 [==============================] - 2s 31ms/step - loss: 0.0027 - accuracy: 0.9994 - val_loss: 0.2665 - val_accuracy: 0.9701
# Epoch 21/44
# 60/60 [==============================] - 2s 32ms/step - loss: 0.0020 - accuracy: 0.9992 - val_loss: 0.3008 - val_accuracy: 0.9667
# Epoch 22/44
# 60/60 [==============================] - 2s 36ms/step - loss: 0.0024 - accuracy: 0.9995 - val_loss: 0.2810 - val_accuracy: 0.9674
# Epoch 23/44
# 60/60 [==============================] - 3s 50ms/step - loss: 0.0018 - accuracy: 0.9996 - val_loss: 0.2630 - val_accuracy: 0.9721
# Epoch 24/44
# 60/60 [==============================] - 2s 37ms/step - loss: 0.0017 - accuracy: 0.9995 - val_loss: 0.3183 - val_accuracy: 0.9667
# Epoch 25/44
# 60/60 [==============================] - 2s 31ms/step - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.3090 - val_accuracy: 0.9680
# Epoch 26/44
# 60/60 [==============================] - 2s 31ms/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.3151 - val_accuracy: 0.9680
# Epoch 27/44
# 60/60 [==============================] - 2s 31ms/step - loss: 0.0016 - accuracy: 0.9996 - val_loss: 0.2978 - val_accuracy: 0.9704
# Epoch 28/44
# 60/60 [==============================] - 2s 32ms/step - loss: 0.0012 - accuracy: 0.9996 - val_loss: 0.2871 - val_accuracy: 0.9714
# Epoch 29/44
# 60/60 [==============================] - 2s 36ms/step - loss: 0.0012 - accuracy: 0.9996 - val_loss: 0.2734 - val_accuracy: 0.9738
# Epoch 30/44
# 60/60 [==============================] - 2s 37ms/step - loss: 0.9336 - accuracy: 0.8836 - val_loss: 0.4993 - val_accuracy: 0.7531
# Epoch 31/44
# 60/60 [==============================] - 2s 31ms/step - loss: 0.3140 - accuracy: 0.8634 - val_loss: 0.3018 - val_accuracy: 0.8739
# Epoch 32/44
# 60/60 [==============================] - 2s 32ms/step - loss: 0.1264 - accuracy: 0.9539 - val_loss: 0.2127 - val_accuracy: 0.9344
# Epoch 33/44
# 60/60 [==============================] - 2s 31ms/step - loss: 0.0443 - accuracy: 0.9870 - val_loss: 0.2491 - val_accuracy: 0.9384
# Epoch 34/44
# 60/60 [==============================] - 2s 34ms/step - loss: 0.0172 - accuracy: 0.9959 - val_loss: 0.1747 - val_accuracy: 0.9650
# Epoch 35/44
# 60/60 [==============================] - 2s 31ms/step - loss: 0.0055 - accuracy: 0.9994 - val_loss: 0.2075 - val_accuracy: 0.9610
# Epoch 36/44
# 60/60 [==============================] - 2s 38ms/step - loss: 0.0031 - accuracy: 0.9997 - val_loss: 0.2041 - val_accuracy: 0.9660
# Epoch 37/44
# 60/60 [==============================] - 2s 37ms/step - loss: 0.0023 - accuracy: 0.9997 - val_loss: 0.2094 - val_accuracy: 0.9674
# Epoch 38/44
# 60/60 [==============================] - 2s 32ms/step - loss: 0.0019 - accuracy: 0.9997 - val_loss: 0.2512 - val_accuracy: 0.9627
# Epoch 39/44
# 60/60 [==============================] - 2s 31ms/step - loss: 0.0017 - accuracy: 0.9997 - val_loss: 0.2359 - val_accuracy: 0.9667
# Epoch 40/44
# 60/60 [==============================] - 2s 32ms/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.2811 - val_accuracy: 0.9613
# Epoch 41/44
# 60/60 [==============================] - 2s 34ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.2638 - val_accuracy: 0.9654
# Epoch 42/44
# 60/60 [==============================] - 2s 35ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.2958 - val_accuracy: 0.9623
# Epoch 43/44
# 60/60 [==============================] - 2s 37ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.2812 - val_accuracy: 0.9643
# Epoch 44/44
# 60/60 [==============================] - 2s 35ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.2294 - val_accuracy: 0.9734
# Training Complete

# %%
tf.keras.utils.plot_model(model_BiLSTM_8020, show_shapes=True, rankdir="LR")

# %%
# Visualize the results:

plt.plot(history_BiLSTM_8020.history['accuracy'])
plt.plot(history_BiLSTM_8020.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

plt.plot(history_BiLSTM_8020.history['loss'])
plt.plot(history_BiLSTM_8020.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper right')
plt.show()

# %%
pred_8020 = model_BiLSTM_8020.predict(test_data)

binary_predictions_8020 = []

for i in pred_8020:
    if i >= 0.5:
        binary_predictions_8020.append(1)
    else:
        binary_predictions_8020.append(0)
# Out:
# 93/93 [==============================] - 2s 9ms/step

# %%
# Confusion Matrix
from sklearn.metrics import confusion_matrix

matrix = confusion_matrix(binary_predictions_8020, test_labels)
plt.figure(figsize=(5, 5))
ax= plt.subplot()
sns.heatmap(matrix, annot=True, ax = ax, fmt = ".1f")

# labels, title and ticks
ax.set_xlabel('Predicted Labels', size=20)
ax.set_ylabel('True Labels', size=20)
ax.set_title('Confusion Matrix - Traditional Hybrid CNN-BiLSTM with Split Ratio 80:20', size=20) 
ax.xaxis.set_ticklabels(['True News','Fake News'], size=15)
ax.yaxis.set_ticklabels(['True News','Fake News'], size=15)
# Out:
# [Text(0, 0.5, 'True News'), Text(0, 1.5, 'Fake News')]

# %%
# Precision, recall, accuracy score and F1 score

from sklearn import metrics
Accuracy_8020 = metrics.accuracy_score(test_labels, binary_predictions_8020)
Precision_8020 = metrics.precision_score(test_labels, binary_predictions_8020)
Sensitivity_recall_8020 = metrics.recall_score(test_labels, binary_predictions_8020)
Specificity_8020 = metrics.recall_score(test_labels, binary_predictions_8020, pos_label=0)
F1_score_8020 = metrics.f1_score(test_labels, binary_predictions_8020)

print("Accuracy of 80:20 BiLSTM Model =", Accuracy_8020)
print("Precision of 80:20 BiLSTM Model =", Precision_8020)
print("Sensitivity_recall of 80:20 BiLSTM Model =", Sensitivity_recall_8020)
print("Specificity of BiLSTM Model 80:20 =", Specificity_8020)
print("F1_score of BiLSTM Model 80:20 =", F1_score_8020)
# Out:
# Accuracy of 80:20 BiLSTM Model = 0.9734275142953246
# Precision of 80:20 BiLSTM Model = 0.9508867667121419
# Sensitivity_recall of 80:20 BiLSTM Model = 0.9950035688793719
# Specificity of BiLSTM Model 80:20 = 0.9541984732824428
# F1_score of BiLSTM Model 80:20 = 0.9724450645273806

# %% [markdown]
# # **Comparision of Models**

# %%
# Accuracy comparision

plt.plot(history_BiLSTM_9010.history['val_accuracy'])
plt.plot(history_BiLSTM_8020.history['val_accuracy'])
plt.plot(history_BiLSTM_7030.history['val_accuracy'])

plt.title('Traditional Hybrid CNN-BiLSTM Model accuracy Comparision - with different Split Ratio ')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Split Ratio: 90-10', 'Split Ratio: 80-20', 'Split Ratio: 70-30'], loc='lower right')
plt.show()

# %%
# Loss Comparision
plt.plot(history_BiLSTM_9010.history['val_loss'])
plt.plot(history_BiLSTM_8020.history['val_loss'])
plt.plot(history_BiLSTM_7030.history['val_loss'])

plt.title('Traditional Hybrid CNN-BiLSTM Model loss Comparision - with different Split Ratio')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Split Ratio: 90-10', 'Split Ratio: 80-20', 'Split Ratio: 70-30'], loc='upper right')
plt.show()
